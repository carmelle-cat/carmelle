# %% [markdown]
# **colorectal tumor dataset analysis building on work by Li et. al https://pubmed.ncbi.nlm.nih.gov/39216476/**

# %%
import scanpy as sc
import scvi
import pandas as pd

# %% [markdown]
# # load data from crc atlas

# %%
adata_fp ="crc1/10X-Illumina-processed/expr.combined.TPM.h5ad"

with open(adata_fp,'rb') as f:
    adata=sc.read_h5ad(f)

# %%
sc.pl.tsne(adata, color="ClusterMidway")

# %%
sc.pl.tsne(adata, color="ClusterTop", save='crc_atlas_tsne.png')
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# WARNING: saving figure to file figures/tsnecrc_atlas_tsne.png

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 218966 × 16886
#     obs: 'nCount_RNA', 'nFeature_RNA', 'library_id', 'sample_source', 'condition', 'ClusterTop', 'ClusterMidway', 'ClusterFull', 'library_id_short'
#     var: 'features', 'unintegrated_features'
#     uns: 'ClusterMidway_colors'
#     obsm: 'X_tsne'
#     layers: 'unintegrated'

# %% [markdown]
# # visualzing data from Li et al. (we have isoform expression data for these cells only)

# %%
adata.obs["condition_integration"]= adata.obs.apply(lambda row: "c295" if row["sample_source"]=="bc295" else row["condition"], axis=1)

# %%
sc.pl.tsne(adata, color="condition_integration", palette={"c295":"#aaaaaa","normal":"blue","tumor":"red"}, size=1, alpha=0.8, save='Li_data.png')
# Out:
# WARNING: saving figure to file figures/tsneLi_data.png

# %%
adata.obs["ClusterTop_integration"]= adata.obs.apply(lambda row: "c295" if row["sample_source"]=="bc295" else row["ClusterTop"], axis=1)

# %%
sc.pl.tsne(adata, color="ClusterTop_integration", size=1, alpha=0.8, save='li_epithelial.png')
# Out:
# WARNING: saving figure to file figures/tsneli_epithelial.png

# %%
adata.obs['ClusterTop_integration'].value_counts()
# Out:
# ClusterTop_integration
# c295       200000
# Epi         16337
# TNKILC       1360
# B             692
# Myeloid       344
# Plasma        154
# Strom          40
# Mast           39
# Name: count, dtype: int64

# %% [markdown]
# # cluster epithelial cells using their isoform expression

# %%
# in the cells that are identified as epithelial, recluster using isoform data to find isoform programs/transcriptional states

# %%
#long read isoform expression 
lr_isoform_path = '/mnt/lareaulab/carmelle/longread_sc/crc1/PacBio-isoform_counts_matrix_ad.h5ad'

# %%
lr_isoform = sc.read_h5ad(lr_isoform_path)

# %%
lr_isoform
# Out:
# AnnData object with n_obs × n_vars = 287458 × 125205
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'library_id_IL', 'condition', 'ClusterTop', 'ClusterMidway', 'ClusterMidway2', 'ClusterFull', 'ClusterFull2', 'library_id_PB'
#     var: 'chrom', 'start', 'end', 'GeneSymbol', 'SupportingStructCategory', 'WithinCAGEPeak', 'WithinPolyAPeak', 'NExons'

# %%
sc.pp.filter_genes(lr_isoform, min_cells=3)

#have to be very lose with filtering cells because we have very few cells have isoform data to begin with
sc.pp.filter_cells(lr_isoform, min_genes=3)

# %%
sc.pp.calculate_qc_metrics(lr_isoform, inplace=True)

# %%
lr_isoform
# Out:
# AnnData object with n_obs × n_vars = 17760 × 29255
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'library_id_IL', 'condition', 'ClusterTop', 'ClusterMidway', 'ClusterMidway2', 'ClusterFull', 'ClusterFull2', 'library_id_PB', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'chrom', 'start', 'end', 'GeneSymbol', 'SupportingStructCategory', 'WithinCAGEPeak', 'WithinPolyAPeak', 'NExons', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
sc.pl.scatter(lr_isoform, x='total_counts', y='n_genes_by_counts', size=10)

# %%
lr_isoform.obs['condition'].value_counts()
# Out:
# condition
# normal    4406
# tumor     3229
# Name: count, dtype: int64

# %%
lr_isoform.obs['ClusterTop'].value_counts()
# Out:
# ClusterTop
# Epi        6411
# TNKILC      588
# B           377
# Myeloid     143
# Plasma       81
# Mast         25
# Strom        10
# Name: count, dtype: int64

# %%
#It looks like most of our isoform expression data are form epithelial cells so let's try to look at 
#clusters of isoform expression in epithelial cells

epi_iso = lr_isoform[lr_isoform.obs['ClusterTop'] == 'Epi', :].copy()
epi_iso
# Out:
# AnnData object with n_obs × n_vars = 6411 × 29255
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'library_id_IL', 'condition', 'ClusterTop', 'ClusterMidway', 'ClusterMidway2', 'ClusterFull', 'ClusterFull2', 'library_id_PB', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'chrom', 'start', 'end', 'GeneSymbol', 'SupportingStructCategory', 'WithinCAGEPeak', 'WithinPolyAPeak', 'NExons', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
# again, total isoform counts per cell is pretty ok ... but only across an average of 69 isoforms per cell

np.mean(epi_iso.obs['n_genes_by_counts']), np.mean(epi_iso.obs['nCount_RNA'])
# Out:
# (np.float64(69.27234440804867), np.float64(5478.705350179379))

# %%
sc.tl.pca(epi_iso)
sc.pp.neighbors(epi_iso, n_pcs=10, n_neighbors=15)

# %%
sc.pl.pca_variance_ratio(epi_iso, n_pcs=50, log=True)

# %%
#let's try to visualize the epithelial isoform data

sc.tl.pca(epi_iso)
sc.pp.neighbors(epi_iso, n_pcs=10, n_neighbors=15)

# %%
#umap
sc.tl.umap(epi_iso)

# %%
sc.pl.umap(epi_iso, color=['ClusterTop', 'ClusterMidway'])

# %%
#now do leiden clustering on the epithelial cells using isoform data
sc.tl.leiden(epi_iso, resolution=0.01)

# %%
# Test a range of resolutions
for res in [0.01, 0.05, 0.1, 0.2, 0.4]:
    key = 'epithelial_iso_res' + str(res)
    sc.tl.leiden(epi_iso, resolution=res, key_added=key)
    adata.obs[adata_key] = epi_iso.obs[key]
    n_clusters = epi_iso.obs[key].nunique()
    print(f"Resolution {res}: {n_clusters} clusters")
# Out:
# Resolution 0.01: 2 clusters
# Resolution 0.05: 5 clusters
# Resolution 0.1: 8 clusters
# Resolution 0.2: 12 clusters
# Resolution 0.4: 16 clusters

# %%
sc.pl.umap(epi_iso, color=['epithelial_iso_res0.01', 'epithelial_iso_res0.05', 'epithelial_iso_res0.1', 'epithelial_iso_res0.2'])

# %%
#look at some quality metrics to help decide which clusters to do DE and understand the unstable clustering of some cells

epi_iso.obs['log10_counts'] = np.log10(epi_iso.obs['n_genes_by_counts'])
epi_iso.obs['log10_counts_RNA'] = np.log10(epi_iso.obs['nCount_RNA'])

sc.pl.umap(epi_iso, color=['condition','log10_counts', 'log10_counts_RNA'])

# %%
plot_contingency(epi_iso, 'epithelial_iso_res0.01', 'epithelial_iso_res0.05')
plot_contingency(epi_iso, 'epithelial_iso_res0.05', 'epithelial_iso_res0.1')
plot_contingency(epi_iso, 'epithelial_iso_res0.1', 'epithelial_iso_res0.2')

# %%
# from analyzing the leiden clusters and the quality metrics (read counts per cell), looking at resolution 0.1 and comparing
# between cluster 0 and cluster 3 seem to be most promosing

print('cluster 2', epi_iso[epi_iso.obs['epithelial_iso_res0.2'] == '2'].obs['condition'].value_counts())
print('cluster 8', epi_iso[epi_iso.obs['epithelial_iso_res0.2'] == '3'].obs['condition'].value_counts())

# cluster 2 is a mix of tumor and normal cells
# cluster 3 is a tumor only cluster

sc.pl.umap(epi_iso, color=['epithelial_iso_res0.1', 'log10_counts_RNA', 'condition'], save='epi_only_umap.png')
# Out:
# cluster 2 condition
# tumor     682
# normal    465
# Name: count, dtype: int64
# cluster 8 condition
# normal    520
# tumor     146
# Name: count, dtype: int64
# WARNING: saving figure to file figures/umapepi_only_umap.png

# %% [markdown]
# # idenity top marker isoforms for epithelial subcluster 2 and subcluster 3

# %%
# first lets map back these subclusters in the atlast, where are they?
adata.obs["epi_subclusters"] = epi_iso.obs['epithelial_iso_res0.1']

# %%
adata.obs['epi_subclusters']. value_counts()
# Out:
# epi_subclusters
# 0    2030
# 1    1407
# 2    1121
# 3     560
# 4     442
# 5     288
# 6     288
# 7     269
# Name: count, dtype: int64

# %%
sc.pl.tsne(adata, color=["epi_subclusters"], groups=['2', '3'], size=10)

# %%
sc.pp.log1p(epi_iso)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
# now let's look at the top isoforms expressed in the clusters

sc.tl.rank_genes_groups(epi_iso, 'epithelial_iso_res0.1', groups=['2', '3'], method='wilcoxon', n_genes=29255)

# %%
cluster2_de = create_de_df(epi_iso, '2')
cluster2_de.head()
# Out:
# /tmp/ipykernel_3962127/2942278159.py:12: RuntimeWarning: divide by zero encountered in log10
#   pvals_adj = -np.log10(results['pvals_adj'][cluster])
#              gene    log2fc  -log10(pval_adj)           pval color
# 0  TCONS_00017589  3.136863               inf   0.000000e+00  gray
# 1  TCONS_00100539  4.069408               inf   0.000000e+00  gray
# 2  TCONS_00058781  4.255840               inf   0.000000e+00  gray
# 3  TCONS_00043046  3.073705        302.516760  4.160065e-307  gray
# 4  TCONS_00024772  3.594557        281.394308  6.893846e-286  gray

# %%
plot_volcano(cluster2_de.drop([x for x in range(0, 50)]), 'cluster 2 top genes')

# %%
cluster3_de = create_de_df(epi_iso, '3')
cluster3_de.head()
# Out:
# /tmp/ipykernel_3962127/2942278159.py:12: RuntimeWarning: divide by zero encountered in log10
#   pvals_adj = -np.log10(results['pvals_adj'][cluster])
#              gene    log2fc  -log10(pval_adj)           pval color
# 0  TCONS_00121692  4.294308               inf   0.000000e+00  gray
# 1  TCONS_00121689  4.510530        130.905825  8.491903e-136  gray
# 2  TCONS_00121688  4.876695        103.762614  1.771363e-108  gray
# 3  TCONS_00121690  6.131448         86.710767   2.661294e-91  gray
# 4  TCONS_00075152  2.795751         45.872880   2.290289e-50  gray

# %%
plot_volcano(cluster3_de, 'cluster 3')

# %%
# remove the p-val outlier
plot_volcano(cluster3_de.drop([0,1,2,3]), 'cluster 3')

# %%
# let's look at the isoforms up/downregulated at of our tumor epithelial cells. what makes them different?

#filter for significance
cluster3_de = cluster3_de[cluster3_de['-log10(pval_adj)'].apply(lambda x: x < -np.log10(0.05))]

# dont look at the outliers > 20 and < - 20 fold changes
cluster3_de = cluster3_de[cluster3_de.log2fc.apply(lambda x: (x < 10) and (x > -10))]
cluster3_de
# Out:
#           gene    log2fc  -log10(pval_adj)      pval  color
# 162    ATP5F1E  3.662842          1.289105  0.000292    red
# 163    SELENOW  1.891654          1.158917  0.000396    red
# 164       IGF2  6.274055          1.113591  0.000442    red
# 165    PIK3C2A  1.902920          1.107696  0.000451    red
# 166       PFN1  2.244021          1.046388  0.000522    red
# ...        ...       ...               ...       ...    ...
# 29248   TSPAN8 -1.775381          0.043647  0.007393  green
# 29249      CKB -1.291084          0.055143  0.007136  green
# 29250   MALAT1 -1.889045          0.390660  0.002975  green
# 29251    EPCAM -2.174887          0.825817  0.000934  green
# 29252      UBC -2.336296          1.297266  0.000284  green
#
# [9183 rows x 5 columns]

# %%
# let's look at top upregulated
cluster3_top_up = cluster3_de.sort_values('log2fc', ascending=False)[:20]
cluster3_top_up
# Out:
#          gene    log2fc  -log10(pval_adj)      pval color
# 248  HSP90AA1  8.798981         -0.000000  0.012057   red
# 235     HSPB1  8.744593          0.013946  0.008044   red
# 286   CEACAM5  8.627992         -0.000000  0.025696   red
# 288    MALAT1  8.454573         -0.000000  0.025702   red
# 364      MPC2  8.148320         -0.000000  0.070113   red
# 427     GRINA  8.075521         -0.000000  0.125628   red
# 408  RNA28SN3  7.949921         -0.000000  0.109284   red
# 428       POR  7.912542         -0.000000  0.125643   red
# 500     H3C14  7.799901         -0.000000  0.186240   red
# 535      PFKL  7.711470         -0.000000  0.210618   red
# 570   TMEM259  7.617375         -0.000000  0.237225   red
# 536     RABL6  7.599845         -0.000000  0.210631   red
# 537       H19  7.599845         -0.000000  0.210631   red
# 571     PLOD3  7.552257         -0.000000  0.237235   red
# 594      PAK2  7.432548         -0.000000  0.266139   red
# 629     ALDOA  7.379102         -0.000000  0.297369   red
# 631   TMEM63A  7.302181         -0.000000  0.297380   red
# 630      PFKL  7.302181         -0.000000  0.297380   red
# 668       VCP  7.243655         -0.000000  0.330969   red
# 667      BOP1  7.243655         -0.000000  0.330969   red

# %% [markdown]
# # convert TCONS id to gene ID of top up and down regulated isoforms

# %%
tcons_to_ensembl = transcript_name_converter(cluster3_de['gene'].tolist())
ensembl_to_symbol = get_gene_symbols(tcons_to_ensembl)
cluster3_de['gene'] = ensembl_to_symbol

# %%
# let's look at top upregulated
cluster3_top_up = cluster3_de.sort_values('log2fc', ascending=False)[:20]
cluster3_top_down = cluster3_de.sort_values('log2fc', ascending=True)[:20]

# %%
cluster3_top_up[['gene', 'log2fc', '-log10(pval_adj)', 'pval']].reset_index()
# Out:
#     index      gene    log2fc  -log10(pval_adj)      pval
# 0     248  HSP90AA1  8.798981         -0.000000  0.012057
# 1     235     HSPB1  8.744593          0.013946  0.008044
# 2     286   CEACAM5  8.627992         -0.000000  0.025696
# 3     288    MALAT1  8.454573         -0.000000  0.025702
# 4     364      MPC2  8.148320         -0.000000  0.070113
# 5     427     GRINA  8.075521         -0.000000  0.125628
# 6     408  RNA28SN3  7.949921         -0.000000  0.109284
# 7     428       POR  7.912542         -0.000000  0.125643
# 8     500     H3C14  7.799901         -0.000000  0.186240
# 9     535      PFKL  7.711470         -0.000000  0.210618
# 10    570   TMEM259  7.617375         -0.000000  0.237225
# 11    536     RABL6  7.599845         -0.000000  0.210631
# 12    537       H19  7.599845         -0.000000  0.210631
# 13    571     PLOD3  7.552257         -0.000000  0.237235
# 14    594      PAK2  7.432548         -0.000000  0.266139
# 15    629     ALDOA  7.379102         -0.000000  0.297369
# 16    631   TMEM63A  7.302181         -0.000000  0.297380
# 17    630      PFKL  7.302181         -0.000000  0.297380
# 18    668       VCP  7.243655         -0.000000  0.330969
# 19    667      BOP1  7.243655         -0.000000  0.330969

# %%
cluster3_top_down[['gene', 'log2fc', '-log10(pval_adj)', 'pval']].reset_index()
# Out:
#     index       gene    log2fc  -log10(pval_adj)      pval
# 0   29236       LDHB -4.944178              -0.0  0.094738
# 1   29211     SPINT2 -4.793006              -0.0  0.201835
# 2   29231     TMEM59 -4.671941              -0.0  0.122756
# 3   29220    GABARAP -4.527053              -0.0  0.158717
# 4   29209    COX7A2L -4.380103              -0.0  0.214184
# 5   29204        TXN -4.293177              -0.0  0.224301
# 6   29186      UBXN1 -4.135408              -0.0  0.300822
# 7   29179       MDH1 -4.073346              -0.0  0.329847
# 8   29181      NR2F6 -4.048501              -0.0  0.316793
# 9   29178        FOS -3.998782              -0.0  0.329919
# 10  29138   HSP90AA1 -3.956887              -0.0  0.411851
# 11  29162      VDAC2 -3.954808              -0.0  0.353688
# 12  29153      PRDX3 -3.885666              -0.0  0.378545
# 13  29223       CFL1 -3.876588              -0.0  0.142062
# 14  29243       YBX1 -3.817230              -0.0  0.037212
# 15  29225       EEF2 -3.747261              -0.0  0.138571
# 16  29131  GABARAPL2 -3.725565              -0.0  0.423591
# 17  29117       OSTC -3.691906              -0.0  0.463302
# 18  29113      YWHAH -3.670910              -0.0  0.471472
# 19  29216      SRSF9 -3.655420              -0.0  0.177884

# %%
epi_iso.var_names
# Out:
# Index(['TCONS_00011260', 'TCONS_00000001', 'TCONS_00002271', 'TCONS_00000002',
#        'TCONS_00002276', 'TCONS_00002278', 'TCONS_00000003', 'TCONS_00000004',
#        'TCONS_00000005', 'TCONS_00000007',
#        ...
#        'TCONS_00125063', 'TCONS_00125038', 'TCONS_00125039', 'TCONS_00125043',
#        'TCONS_00125064', 'TCONS_00125065', 'TCONS_00125074', 'TCONS_00125113',
#        'TCONS_00125114', 'TCONS_00125048'],
#       dtype='object', length=29255)

# %%
ensembl_to_name = ensembl_to_name.set_index('gene_symbol')

# %%
ensembl_to_name.loc['SRSF9'], ensembl_to_name.loc['YBX1'], ensembl_to_name.loc['EEF2']
# Out:
# (gene_id    ENSG00000111786
#  Name: SRSF9, dtype: object,
#  gene_id    ENSG00000065978
#  Name: YBX1, dtype: object,
#  gene_id    ENSG00000167658
#  Name: EEF2, dtype: object)

# %%
[x for x in gene_to_tcons.keys() if 'ENSG00000111786' in x]
# Out:
# ['GENCODE__ENSG00000111786.10']

# %%
[x for x in gene_to_tcons.keys() if 'ENSG00000065978' in x]
# Out:
# ['GENCODE__ENSG00000065978.19']

# %%
[x for x in gene_to_tcons.keys() if 'ENSG00000167658' in x]
# Out:
# ['GENCODE__ENSG00000167658.16']

# %%
gene_to_tcons['GENCODE__ENSG00000111786.10'], gene_to_tcons['GENCODE__ENSG00000065978.19'], gene_to_tcons['GENCODE__ENSG00000167658.16']
# Out:
# ('TCONS_00028827', 'TCONS_00000335', 'TCONS_00059174')

# %%
sub_adata
# Out:
# AnnData object with n_obs × n_vars = 1681 × 29255
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'library_id_IL', 'condition', 'ClusterTop', 'ClusterMidway', 'ClusterMidway2', 'ClusterFull', 'ClusterFull2', 'library_id_PB', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'leiden', 'epithelial_iso_res0.01', 'epithelial_iso_res0.05', 'epithelial_iso_res0.1', 'epithelial_iso_res0.2', 'epithelial_iso_res0.4', 'log10_counts', 'log10_counts_RNA'
#     var: 'chrom', 'start', 'end', 'GeneSymbol', 'SupportingStructCategory', 'WithinCAGEPeak', 'WithinPolyAPeak', 'NExons', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'pca', 'neighbors', 'umap', 'leiden', 'epithelial_iso_res0.01', 'epithelial_iso_res0.05', 'epithelial_iso_res0.1', 'epithelial_iso_res0.2', 'epithelial_iso_res0.4', 'condition_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.pp.log1p(epi_iso)

# %%
sub_adata = epi_iso[epi_iso.obs['epithelial_iso_res0.1'].isin(['2', '3'])].copy()
gene_list = ['TCONS_00028827', 'TCONS_00000335', 'TCONS_00059174']
sc.pl.umap(epi_iso, color=gene_list)

# %% [markdown]
# # helper functions

# %%
def plot_volcano(plotting_df, title): 
    plt.figure(figsize=(4, 3))
    plt.scatter(x=plotting_df['log2fc'], y=plotting_df['-log10(pval_adj)'], c=plotting_df['color'], s=10, alpha=0.7)
    
    # 4. Add reference lines for significance and fold change
    plt.axhline(y=pval_thresh, color='black', linestyle='--', linewidth=1)
    plt.axvline(x=log2fc_thresh, color='black', linestyle='--', linewidth=1)
    plt.axvline(x=-log2fc_thresh, color='black', linestyle='--', linewidth=1)
    
    
    plt.xlabel('Log₂ Fold Change')
    plt.ylabel('-log 10 (p-value)')
    plt.title(title)
    plt.grid(True, linestyle=':', alpha=0.6)
    
    plt.show()

# %%
# Define significance thresholds
pval_thresh = -np.log10(0.05)
log2fc_thresh = 1

def create_de_df(adata, cluster):
    # Access rank_genes_groups from adata
    results = adata.uns['rank_genes_groups']
    
    # Extract data for the specific cluster

    logfc = results['logfoldchanges'][cluster]
    pvals_adj = -np.log10(results['pvals_adj'][cluster])
    pvals = results['pvals'][cluster]
    genes = results['names'][cluster]
    
    
    plotting_df = pd.DataFrame({'gene': genes, 'log2fc': logfc, '-log10(pval_adj)': pvals_adj, 'pval': pvals})
    
    #significant up/down (red/green) not significant (gray)
    plotting_df['color'] = 'gray' # Default color
    plotting_df.loc[(plotting_df['-log10(pval_adj)'] < pval_thresh) & (plotting_df['log2fc'] > log2fc_thresh), 'color'] = 'red'    # Upregulated
    plotting_df.loc[(plotting_df['-log10(pval_adj)'] < pval_thresh) & (plotting_df['log2fc'] < -log2fc_thresh), 'color'] = 'green' # Downregulated

    return plotting_df

# %%
import seaborn as sns

def plot_contingency(adata, key1, key2):
    contingency = pd.crosstab(
    adata.obs[key1],  
    adata.obs[key2],
    normalize='columns')
    
    plt.figure(figsize=(5.5, 3.5))
    sns.heatmap(contingency, annot=True, fmt='.2f', cmap='YlOrRd', cbar_kws={'label': 'Proportion'})
    plt.xlabel(key2)
    plt.ylabel(key1)
    plt.title('Cluster Correspondence')
    plt.tight_layout()
    plt.show()

# %%
# the andata var hold the TCONS id conversion
epi_iso.var['GeneSymbol']
# Out:
# TCONS_00011259                    novelGene_RefSeq__LOC124900618_AS
# TCONS_00011260                           GENCODE__ENSG00000225972.1
# TCONS_00007975                           GENCODE__ENSG00000225972.1
# TCONS_00000001                           GENCODE__ENSG00000225630.1
# TCONS_00009624                           GENCODE__ENSG00000237973.1
#                                         ...
# TCONS_00125121              novelGene_GENCODE__ENSG00000230029.1_AS
# TCONS_00125205                                       novelGene_1086
# TCONS_00125151                                         LOC105377236
# TCONS_00125152                                       novelGene_1087
# TCONS_00125153    GENCODE__ENSG00000229238.3___GENCODE__ENSG0000...
# Name: GeneSymbol, Length: 125205, dtype: category
# Categories (20151, object): ['AKAP17A', 'ANAPC1P2', 'ANP32A-IT1', 'ARHGAP27P1', ..., 'novelGene_RefSeq__LOC124906230_AS', 'novelGene_RefSeq__LOC124906254_AS', 'novelGene_RefSeq__LOC124909408_AS', 'novelGene_RefSeq__LOC127814297_AS']

# %%
# create a conversion map TCONS ID -> ENSEMBL ID -> GENE SYMBOL
# this is TCONS ID -> ENSEMBL ID 
ensembl_convert = dict(zip(lr_isoform.var['GeneSymbol'].index, lr_isoform.var['GeneSymbol'].values))

ensembl_ids = []

for x in ensembl_convert.values():
    try:
        ensembl_ids.append(x.split('__')[1].split('.')[0])
    except IndexError:
        ensembl_ids.append(x)

# %%
# now do ENSEMBL ID -> GENE SYMBOL
from pybiomart import Server

server = Server(host='http://www.ensembl.org')
mart = server['ENSEMBL_MART_ENSEMBL']
dataset = mart['hsapiens_gene_ensembl']

ensembl_to_name = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'])

ensembl_to_name.columns = ['gene_id', 'gene_symbol']
ensembl_to_name = ensembl_to_name[ensembl_to_name['gene_symbol'].notna()]
ensembl_to_name.head()
# Out:
#            gene_id gene_symbol
# 0  ENSG00000210049       MT-TF
# 1  ENSG00000211459     MT-RNR1
# 2  ENSG00000210077       MT-TV
# 3  ENSG00000210082     MT-RNR2
# 4  ENSG00000209082      MT-TL1

# %%
def get_gene_symbols(id_list):
    names = []
    ensembl = ensembl_to_name.set_index('gene_id')
    for x in id_list:
        try:
            names.append(ensembl.loc[x]['gene_symbol'])
        except KeyError:
            names.append(x)
    return names

# %%
def transcript_name_converter(id_list):
    ensembl_id = []
    clean_ids = []
    
    for x in id_list:
        ensembl_id.append(ensembl_convert[x])
    
    for y in ensembl_id:
        try:
            id_clean = y.split('__')[1].split('.')[0]
            clean_ids.append(id_clean)  
        except IndexError:
            clean_ids.append(y)
    return clean_ids

# %%
gene_to_tcons =  dict(zip(lr_isoform.var['GeneSymbol'].values, lr_isoform.var['GeneSymbol'].index))

# %%
clean
# Out:
# {'GENCODE__ENSG00000225972.1': 'TCONS_00011260',
#  'GENCODE__ENSG00000225630.1': 'TCONS_00000001',
#  'GENCODE__ENSG00000228794.12': 'TCONS_00002271',
#  'GENCODE__ENSG00000187608.10': 'TCONS_00000002',
#  'GENCODE__ENSG00000188157.15': 'TCONS_00002276',
#  'RefSeq__LOC124903818': 'TCONS_00000003',
#  'GENCODE__ENSG00000272141.1': 'TCONS_00000004',
#  'GENCODE__ENSG00000176022.7': 'TCONS_00000005',
#  'GENCODE__ENSG00000169972.13': 'TCONS_00007980',
#  'GENCODE__ENSG00000224051.7': 'TCONS_00000012',
#  'GENCODE__ENSG00000224870.9': 'TCONS_00006082',
#  'GENCODE__ENSG00000272455.1': 'TCONS_00002289',
#  'GENCODE__ENSG00000179403.12': 'TCONS_00000016',
#  'GENCODE__ENSG00000160072.20': 'TCONS_00000019',
#  'GENCODE__ENSG00000197785.14': 'TCONS_00006086',
#  'GENCODE__ENSG00000197530.13': 'TCONS_00000022',
#  'GENCODE__ENSG00000067606.17': 'TCONS_00002307',
#  'GENCODE__ENSG00000157916.20': 'TCONS_00000028',
#  'GENCODE__ENSG00000272449.3': 'TCONS_00000032',
#  'GENCODE__ENSG00000157873.18': 'TCONS_00011274',
#  'GENCODE__ENSG00000228037.1': 'TCONS_00006107',
#  'GENCODE__ENSG00000157870.17': 'TCONS_00000042',
#  'GENCODE__ENSG00000130762.15': 'TCONS_00002319',
#  'GENCODE__ENSG00000158109.15': 'TCONS_00002322',
#  'GENCODE__ENSG00000169598.17': 'TCONS_00000044',
#  'GENCODE__ENSG00000158286.13': 'TCONS_00006117',
#  'GENCODE__ENSG00000187017.18': 'TCONS_00000056',
#  'GENCODE__ENSG00000204859.13': 'TCONS_00002340',
#  'GENCODE__ENSG00000041988.16': 'TCONS_00000058',
#  'GENCODE__ENSG00000171735.21': 'TCONS_00000061',
#  'GENCODE__ENSG00000049245.13': 'TCONS_00000064',
#  'GENCODE__ENSG00000049246.15': 'TCONS_00000065',
#  'GENCODE__ENSG00000116288.13': 'TCONS_00000070',
#  'GENCODE__ENSG00000171621.14': 'TCONS_00008005',
#  'GENCODE__ENSG00000171612.7': 'TCONS_00002351',
#  'GENCODE__ENSG00000173614.14': 'TCONS_00002358',
#  'GENCODE__ENSG00000130939.20': 'TCONS_00002365',
#  'GENCODE__ENSG00000054523.20': 'TCONS_00002367',
#  'GENCODE__ENSG00000142657.21': 'TCONS_00006134',
#  'GENCODE__ENSG00000175279.22': 'TCONS_00002374',
#  'GENCODE__ENSG00000142655.13': 'TCONS_00006138',
#  'GENCODE__ENSG00000120948.19': 'TCONS_00011286',
#  'GENCODE__ENSG00000120942.14': 'TCONS_00000087',
#  'GENCODE__ENSG00000132879.14': 'TCONS_00000088',
#  'GENCODE__ENSG00000116663.11': 'TCONS_00000089',
#  'GENCODE__ENSG00000177674.16': 'TCONS_00002383',
#  'GENCODE__ENSG00000011021.23': 'TCONS_00000094',
#  'GENCODE__ENSG00000285646.2': 'TCONS_00002386',
#  'GENCODE__ENSG00000083444.17': 'TCONS_00002388',
#  'GENCODE__ENSG00000116691.11': 'TCONS_00002393',
#  'GENCODE__ENSG00000028137.19': 'TCONS_00002396',
#  'GENCODE__ENSG00000116731.23': 'TCONS_00002407',
#  'GENCODE__ENSG00000171729.14': 'TCONS_00000108',
#  'GENCODE__ENSG00000142634.13': 'TCONS_00000109',
#  'GENCODE__ENSG00000116138.13': 'TCONS_00002413',
#  'GENCODE__ENSG00000197312.13': 'TCONS_00002414',
#  'GENCODE__ENSG00000215695.2': 'TCONS_00002417',
#  'GENCODE__ENSG00000116786.13': 'TCONS_00009687',
#  'GENCODE__ENSG00000162460.7': 'TCONS_00006159',
#  'GENCODE__ENSG00000162458.13': 'TCONS_00000113',
#  'GENCODE__ENSG00000065526.13': 'TCONS_00009697',
#  'GENCODE__ENSG00000055070.17': 'TCONS_00000116',
#  'GENCODE__ENSG00000157191.20': 'TCONS_00002435',
#  'GENCODE__ENSG00000058453.17': 'TCONS_00002439',
#  'GENCODE__ENSG00000074964.17': 'TCONS_00006172',
#  'GENCODE__ENSG00000053372.5': 'TCONS_00000127',
#  'GENCODE__ENSG00000040487.13': 'TCONS_00000129',
#  'GENCODE__ENSG00000173436.15': 'TCONS_00002453',
#  'RPS14P3': 'TCONS_00000131',
#  'GENCODE__ENSG00000158747.15': 'TCONS_00002457',
#  'GENCODE__ENSG00000162543.6': 'TCONS_00002464',
#  'GENCODE__ENSG00000158825.6': 'TCONS_00000133',
#  'GENCODE__ENSG00000158828.8': 'TCONS_00000134',
#  'GENCODE__ENSG00000218510.9': 'TCONS_00006183',
#  'GENCODE__ENSG00000070831.18': 'TCONS_00000136',
#  'GENCODE__ENSG00000184677.18': 'TCONS_00000137',
#  'GENCODE__ENSG00000173372.18': 'TCONS_00000138',
#  'GENCODE__ENSG00000159189.13': 'TCONS_00002475',
#  'GENCODE__ENSG00000173369.18': 'TCONS_00000141',
#  'GENCODE__ENSG00000133216.17': 'TCONS_00011321',
#  'GENCODE__ENSG00000004487.18': 'TCONS_00008036',
#  'GENCODE__ENSG00000142676.14': 'TCONS_00000148',
#  'GENCODE__ENSG00000011007.13': 'TCONS_00000153',
#  'GENCODE__ENSG00000057757.10': 'TCONS_00002505',
#  'GENCODE__ENSG00000011009.12': 'TCONS_00000155',
#  'GENCODE__ENSG00000189266.13': 'TCONS_00009734',
#  'LOC105376863': 'TCONS_00006197',
#  'GENCODE__ENSG00000001461.17': 'TCONS_00000158',
#  'GENCODE__ENSG00000117602.13': 'TCONS_00006198',
#  'GENCODE__ENSG00000133226.19': 'TCONS_00008049',
#  'GENCODE__ENSG00000169504.15': 'TCONS_00002523',
#  'GENCODE__ENSG00000183726.11': 'TCONS_00000172',
#  'GENCODE__ENSG00000204178.11': 'TCONS_00002526',
#  'GENCODE__ENSG00000157978.12': 'TCONS_00002530',
#  'GENCODE__ENSG00000117640.18': 'TCONS_00006208',
#  'GENCODE__ENSG00000142684.9': 'TCONS_00000177',
#  'GENCODE__ENSG00000142675.18': 'TCONS_00006210',
#  'GENCODE__ENSG00000142669.15': 'TCONS_00000185',
#  'GENCODE__ENSG00000169442.9': 'TCONS_00006212',
#  'GENCODE__ENSG00000117682.18': 'TCONS_00000192',
#  'GENCODE__ENSG00000198830.12': 'TCONS_00000193',
#  'GENCODE__ENSG00000117676.14': 'TCONS_00000199',
#  'GENCODE__ENSG00000117713.21': 'TCONS_00000203',
#  'GENCODE__ENSG00000060642.12': 'TCONS_00002563',
#  'GENCODE__ENSG00000204160.12': 'TCONS_00009777',
#  'GENCODE__ENSG00000175793.12': 'TCONS_00000205',
#  'GENCODE__ENSG00000090273.14': 'TCONS_00000209',
#  'GENCODE__ENSG00000186501.15': 'TCONS_00000220',
#  'GENCODE__ENSG00000142765.18': 'TCONS_00002581',
#  'GENCODE__ENSG00000117758.14': 'TCONS_00002592',
#  'GENCODE__ENSG00000117751.18': 'TCONS_00002594',
#  'GENCODE__ENSG00000130775.16': 'TCONS_00002597',
#  'GENCODE__ENSG00000130768.15': 'TCONS_00006234',
#  'GENCODE__ENSG00000158156.9': 'TCONS_00002600',
#  'GENCODE__ENSG00000130770.18': 'TCONS_00008067',
#  'GENCODE__ENSG00000130772.14': 'TCONS_00000231',
#  'GENCODE__ENSG00000204138.13': 'TCONS_00002604',
#  'GENCODE__ENSG00000242125.3': 'TCONS_00000235',
#  'GENCODE__ENSG00000180198.17': 'TCONS_00002610',
#  'GENCODE__ENSG00000180098.9': 'TCONS_00002614',
#  'GENCODE__ENSG00000162419.13': 'TCONS_00002617',
#  'GENCODE__ENSG00000198492.16': 'TCONS_00000241',
#  'GENCODE__ENSG00000159023.23': 'TCONS_00002631',
#  'GENCODE__ENSG00000237329.2': 'TCONS_00002633',
#  'GENCODE__ENSG00000121766.16': 'TCONS_00000244',
#  'GENCODE__ENSG00000168528.12': 'TCONS_00000248',
#  'GENCODE__ENSG00000142910.16': 'TCONS_00006260',
#  'GENCODE__ENSG00000121774.18': 'TCONS_00008079',
#  'GENCODE__ENSG00000121775.18': 'TCONS_00002652',
#  'GENCODE__ENSG00000084652.16': 'TCONS_00000259',
#  'GENCODE__ENSG00000160050.16': 'TCONS_00000260',
#  'GENCODE__ENSG00000084623.12': 'TCONS_00002662',
#  'GENCODE__ENSG00000182866.18': 'TCONS_00002667',
#  'GENCODE__ENSG00000116478.12': 'TCONS_00002672',
#  'GENCODE__ENSG00000162521.19': 'TCONS_00008089',
#  'GENCODE__ENSG00000162522.11': 'TCONS_00002692',
#  'GENCODE__ENSG00000116497.18': 'TCONS_00000267',
#  'GENCODE__ENSG00000121905.10': 'TCONS_00006275',
#  'GENCODE__ENSG00000189433.7': 'TCONS_00006277',
#  'GENCODE__ENSG00000188910.8': 'TCONS_00002700',
#  'GENCODE__ENSG00000146463.12': 'TCONS_00002704',
#  'GENCODE__ENSG00000229994.1': 'TCONS_00002707',
#  'GENCODE__ENSG00000116863.11': 'TCONS_00002712',
#  'GENCODE__ENSG00000054118.15': 'TCONS_00002720',
#  'GENCODE__ENSG00000163874.11': 'TCONS_00002724',
#  'GENCODE__ENSG00000163879.11': 'TCONS_00000285',
#  'GENCODE__ENSG00000134690.11': 'TCONS_00000286',
#  'GENCODE__ENSG00000185090.15': 'TCONS_00008102',
#  'GENCODE__ENSG00000197982.14': 'TCONS_00000288',
#  'GENCODE__ENSG00000183520.12': 'TCONS_00006292',
#  'GENCODE__ENSG00000174574.16': 'TCONS_00008105',
#  'GENCODE__ENSG00000168653.11': 'TCONS_00009020',
#  'GENCODE__ENSG00000127603.32': 'TCONS_00011390',
#  'GENCODE__ENSG00000084072.17': 'TCONS_00002750',
#  'GENCODE__ENSG00000168389.18': 'TCONS_00000303',
#  'GENCODE__ENSG00000131236.18': 'TCONS_00011400',
#  'GENCODE__ENSG00000117000.9': 'TCONS_00002763',
#  'GENCODE__ENSG00000084073.10': 'TCONS_00009031',
#  'GENCODE__ENSG00000084070.12': 'TCONS_00000315',
#  'GENCODE__ENSG00000066136.21': 'TCONS_00011405',
#  'GENCODE__ENSG00000171793.17': 'TCONS_00009862',
#  'GENCODE__ENSG00000044012.4': 'TCONS_00006319',
#  'GENCODE__ENSG00000177181.15': 'TCONS_00002778',
#  'GENCODE__ENSG00000127125.9': 'TCONS_00000322',
#  'GENCODE__ENSG00000171960.12': 'TCONS_00000330',
#  'GENCODE__ENSG00000065978.19': 'TCONS_00000335',
#  'GENCODE__ENSG00000164008.17': 'TCONS_00000338',
#  'GENCODE__ENSG00000164011.18': 'TCONS_00002800',
#  'GENCODE__ENSG00000179178.11': 'TCONS_00002804',
#  'GENCODE__ENSG00000117399.14': 'TCONS_00002805',
#  'GENCODE__ENSG00000142949.17': 'TCONS_00009040',
#  'GENCODE__ENSG00000066135.13': 'TCONS_00002819',
#  'GENCODE__ENSG00000132768.14': 'TCONS_00002821',
#  'GENCODE__ENSG00000117410.14': 'TCONS_00000350',
#  'GENCODE__ENSG00000117411.18': 'TCONS_00006357',
#  'GENCODE__ENSG00000159214.13': 'TCONS_00008136',
#  'GENCODE__ENSG00000178028.14': 'TCONS_00002835',
#  'GENCODE__ENSG00000187147.19': 'TCONS_00009893',
#  'GENCODE__ENSG00000142945.13': 'TCONS_00006361',
#  'GENCODE__ENSG00000142937.12': 'TCONS_00000369',
#  'GENCODE__ENSG00000173846.13': 'TCONS_00000371',
#  'GENCODE__ENSG00000126088.14': 'TCONS_00000372',
#  'GENCODE__ENSG00000186603.7': 'TCONS_00000375',
#  'GENCODE__ENSG00000132773.12': 'TCONS_00002845',
#  'GENCODE__ENSG00000117448.14': 'TCONS_00006371',
#  'GENCODE__ENSG00000132780.17': 'TCONS_00000389',
#  'GENCODE__ENSG00000159596.7': 'TCONS_00000390',
#  'GENCODE__ENSG00000086015.23': 'TCONS_00008144',
#  'GENCODE__ENSG00000117472.10': 'TCONS_00008145',
#  'GENCODE__ENSG00000085999.13': 'TCONS_00002874',
#  'GENCODE__ENSG00000173660.12': 'TCONS_00000399',
#  'GENCODE__ENSG00000117481.11': 'TCONS_00002878',
#  'GENCODE__ENSG00000117480.16': 'TCONS_00000404',
#  'GENCODE__ENSG00000162368.15': 'TCONS_00002886',
#  'GENCODE__ENSG00000186564.6': 'TCONS_00002890',
#  'GENCODE__ENSG00000123080.12': 'TCONS_00009917',
#  'GENCODE__ENSG00000123091.5': 'TCONS_00006405',
#  'GENCODE__ENSG00000117859.19': 'TCONS_00011457',
#  'GENCODE__ENSG00000134717.18': 'TCONS_00002894',
#  'GENCODE__ENSG00000157077.16': 'TCONS_00006415',
#  'GENCODE__ENSG00000134748.13': 'TCONS_00000418',
#  'GENCODE__ENSG00000162378.13': 'TCONS_00000421',
#  'GENCODE__ENSG00000116171.19': 'TCONS_00008158',
#  'GENCODE__ENSG00000226147.1': 'TCONS_00002904',
#  'GENCODE__ENSG00000157184.7': 'TCONS_00002908',
#  'GENCODE__ENSG00000116212.16': 'TCONS_00002912',
#  'GENCODE__ENSG00000116221.15': 'TCONS_00000427',
#  'GENCODE__ENSG00000162390.18': 'TCONS_00002918',
#  'GENCODE__ENSG00000243725.7': 'TCONS_00002919',
#  'GENCODE__ENSG00000143001.6': 'TCONS_00006431',
#  'GENCODE__ENSG00000169174.13': 'TCONS_00008162',
#  'GENCODE__ENSG00000172456.18': 'TCONS_00002936',
#  'GENCODE__ENSG00000134709.13': 'TCONS_00000434',
#  'GENCODE__ENSG00000162599.18': 'TCONS_00006454',
#  'GENCODE__ENSG00000132849.22': 'TCONS_00009950',
#  'GENCODE__ENSG00000240563.2': 'TCONS_00002982',
#  'GENCODE__ENSG00000162607.13': 'TCONS_00011497',
#  'GENCODE__ENSG00000088035.18': 'TCONS_00009079',
#  'GENCODE__ENSG00000079739.17': 'TCONS_00009957',
#  'GENCODE__ENSG00000158966.16': 'TCONS_00002994',
#  'GENCODE__ENSG00000213625.9': 'TCONS_00008183',
#  'GENCODE__ENSG00000198160.15': 'TCONS_00000451',
#  'GENCODE__ENSG00000116717.13': 'TCONS_00003006',
#  'GENCODE__ENSG00000116754.14': 'TCONS_00003015',
#  'GENCODE__ENSG00000116761.12': 'TCONS_00003017',
#  'GENCODE__ENSG00000254685.8': 'TCONS_00000464',
#  'GENCODE__ENSG00000162623.16': 'TCONS_00000466',
#  'GENCODE__ENSG00000117054.15': 'TCONS_00003025',
#  'GENCODE__ENSG00000137955.16': 'TCONS_00003026',
#  'GENCODE__ENSG00000226084.5': 'TCONS_00000470',
#  'GENCODE__ENSG00000137960.6': 'TCONS_00003035',
#  'GENCODE__ENSG00000213560.4': 'TCONS_00003036',
#  'GENCODE__ENSG00000137959.17': 'TCONS_00011519',
#  'GENCODE__ENSG00000137965.11': 'TCONS_00003039',
#  'GENCODE__ENSG00000142875.21': 'TCONS_00008195',
#  'novelGene_41': 'TCONS_00003043',
#  'GENCODE__ENSG00000203943.9': 'TCONS_00006492',
#  'GENCODE__ENSG00000117133.11': 'TCONS_00000475',
#  'GENCODE__ENSG00000142871.18': 'TCONS_00003046',
#  'GENCODE__ENSG00000016490.16': 'TCONS_00006504',
#  'GENCODE__ENSG00000016602.9': 'TCONS_00010004',
#  'GENCODE__ENSG00000097033.15': 'TCONS_00003047',
#  'GENCODE__ENSG00000153936.18': 'TCONS_00003054',
#  'GENCODE__ENSG00000143013.13': 'TCONS_00006516',
#  'GENCODE__ENSG00000065243.20': 'TCONS_00003058',
#  'GENCODE__ENSG00000197147.15': 'TCONS_00000482',
#  'GENCODE__ENSG00000171488.15': 'TCONS_00006523',
#  'GENCODE__ENSG00000171492.14': 'TCONS_00003062',
#  'GENCODE__ENSG00000162664.17': 'TCONS_00000490',
#  'GENCODE__ENSG00000172031.7': 'TCONS_00003071',
#  'GENCODE__ENSG00000122484.9': 'TCONS_00000492',
#  'GENCODE__ENSG00000122406.14': 'TCONS_00003078',
#  'GENCODE__ENSG00000143033.18': 'TCONS_00003084',
#  'GENCODE__ENSG00000117505.13': 'TCONS_00000503',
#  'GENCODE__ENSG00000137942.18': 'TCONS_00003091',
#  'GENCODE__ENSG00000224093.7': 'TCONS_00000506',
#  'GENCODE__ENSG00000117528.14': 'TCONS_00000511',
#  'GENCODE__ENSG00000143036.17': 'TCONS_00006547',
#  'GENCODE__ENSG00000152078.10': 'TCONS_00003103',
#  'GENCODE__ENSG00000122481.17': 'TCONS_00003108',
#  'GENCODE__ENSG00000162627.17': 'TCONS_00003112',
#  'GENCODE__ENSG00000162688.17': 'TCONS_00006559',
#  'GENCODE__ENSG00000117620.15': 'TCONS_00003124',
#  'GENCODE__ENSG00000156875.14': 'TCONS_00003125',
#  'GENCODE__ENSG00000122435.11': 'TCONS_00003129',
#  'GENCODE__ENSG00000137996.13': 'TCONS_00003139',
#  'GENCODE__ENSG00000079335.20': 'TCONS_00003142',
#  'GENCODE__ENSG00000162695.12': 'TCONS_00003147',
#  'GENCODE__ENSG00000233184.9': 'TCONS_00003149',
#  'GENCODE__ENSG00000185946.16': 'TCONS_00010058',
#  'GENCODE__ENSG00000198890.9': 'TCONS_00000527',
#  'GENCODE__ENSG00000260879.1': 'TCONS_00006576',
#  'GENCODE__ENSG00000134186.12': 'TCONS_00006582',
#  'GENCODE__ENSG00000116266.11': 'TCONS_00000533',
#  'GENCODE__ENSG00000121957.15': 'TCONS_00003170',
#  'GENCODE__ENSG00000215717.7': 'TCONS_00000537',
#  'GENCODE__ENSG00000116299.17': 'TCONS_00003177',
#  'GENCODE__ENSG00000031698.13': 'TCONS_00003188',
#  'GENCODE__ENSG00000065135.12': 'TCONS_00006593',
#  'GENCODE__ENSG00000116337.20': 'TCONS_00000547',
#  'GENCODE__ENSG00000168765.19': 'TCONS_00010079',
#  'GENCODE__ENSG00000134184.13': 'TCONS_00003197',
#  'GENCODE__ENSG00000168710.18': 'TCONS_00003200',
#  'GENCODE__ENSG00000143093.15': 'TCONS_00003207',
#  'GENCODE__ENSG00000143119.14': 'TCONS_00003213',
#  'GENCODE__ENSG00000134255.16': 'TCONS_00003216',
#  'GENCODE__ENSG00000116459.11': 'TCONS_00003220',
#  'GENCODE__ENSG00000143110.12': 'TCONS_00003222',
#  'GENCODE__ENSG00000116473.15': 'TCONS_00006613',
#  'GENCODE__ENSG00000064703.13': 'TCONS_00009120',
#  'GENCODE__ENSG00000143079.15': 'TCONS_00003229',
#  'GENCODE__ENSG00000116489.13': 'TCONS_00006617',
#  'GENCODE__ENSG00000155363.19': 'TCONS_00000567',
#  'GENCODE__ENSG00000226419.9': 'TCONS_00000568',
#  'GENCODE__ENSG00000198799.12': 'TCONS_00003242',
#  'GENCODE__ENSG00000081026.19': 'TCONS_00010102',
#  'GENCODE__ENSG00000232499.2': 'TCONS_00003252',
#  'GENCODE__ENSG00000163349.22': 'TCONS_00003257',
#  'GENCODE__ENSG00000116774.12': 'TCONS_00003258',
#  'GENCODE__ENSG00000173218.15': 'TCONS_00008242',
#  'GENCODE__ENSG00000163399.16': 'TCONS_00000585',
#  'GENCODE__ENSG00000116824.5': 'TCONS_00003280',
#  'GENCODE__ENSG00000134247.10': 'TCONS_00006636',
#  'GENCODE__ENSG00000116830.12': 'TCONS_00003285',
#  'GENCODE__ENSG00000198162.12': 'TCONS_00003286',
#  'GENCODE__ENSG00000183508.5': 'TCONS_00003287',
#  'GENCODE__ENSG00000065183.16': 'TCONS_00003291',
#  'GENCODE__ENSG00000092621.13': 'TCONS_00003294',
#  'GENCODE__ENSG00000226067.7': 'TCONS_00003299',
#  'GENCODE__ENSG00000281571.2': 'TCONS_00000597',
#  'LOC100996740': 'TCONS_00010121',
#  'GENCODE__ENSG00000276216.1': 'TCONS_00003305',
#  'GENCODE__ENSG00000117262.19': 'TCONS_00003307',
#  'GENCODE__ENSG00000186141.10': 'TCONS_00003308',
#  'GENCODE__ENSG00000121851.13': 'TCONS_00000600',
#  'GENCODE__ENSG00000287978.1': 'TCONS_00000601',
#  'GENCODE__ENSG00000293279.1': 'TCONS_00003317',
#  'GENCODE__ENSG00000131778.20': 'TCONS_00003319',
#  'GENCODE__ENSG00000280649.2': 'TCONS_00000611',
#  'GENCODE__ENSG00000178104.22': 'TCONS_00011609',
#  'GENCODE__ENSG00000274265.5': 'TCONS_00003333',
#  'GENCODE__ENSG00000286219.2': 'TCONS_00003337',
#  'RefSeq__LINC00869': 'TCONS_00003348',
#  'GENCODE__ENSG00000291158.1': 'TCONS_00000623',
#  'GENCODE__ENSG00000270882.3': 'TCONS_00000627',
#  'GENCODE__ENSG00000290791.1': 'TCONS_00003354',
#  'GENCODE__ENSG00000288859.1': 'TCONS_00010150',
#  'GENCODE__ENSG00000203852.4': 'TCONS_00000630',
#  'GENCODE__ENSG00000184260.6': 'TCONS_00000631',
#  'GENCODE__ENSG00000178096.9': 'TCONS_00000632',
#  'GENCODE__ENSG00000136631.16': 'TCONS_00008277',
#  'GENCODE__ENSG00000023902.14': 'TCONS_00003363',
#  'GENCODE__ENSG00000266472.6': 'TCONS_00000635',
#  'GENCODE__ENSG00000117360.13': 'TCONS_00003366',
#  'GENCODE__ENSG00000143374.18': 'TCONS_00003379',
#  'GENCODE__ENSG00000143369.15': 'TCONS_00003380',
#  'GENCODE__ENSG00000143412.10': 'TCONS_00003388',
#  'GENCODE__ENSG00000143443.10': 'TCONS_00000645',
#  'GENCODE__ENSG00000143458.12': 'TCONS_00003391',
#  'GENCODE__ENSG00000163156.12': 'TCONS_00000648',
#  'GENCODE__ENSG00000143398.20': 'TCONS_00003395',
#  'GENCODE__ENSG00000159352.16': 'TCONS_00000653',
#  'GENCODE__ENSG00000143373.18': 'TCONS_00010164',
#  'GENCODE__ENSG00000159377.11': 'TCONS_00000657',
#  'GENCODE__ENSG00000143375.15': 'TCONS_00000665',
#  'GENCODE__ENSG00000143367.17': 'TCONS_00003410',
#  'GENCODE__ENSG00000223861.1': 'TCONS_00000672',
#  'GENCODE__ENSG00000143376.14': 'TCONS_00000675',
#  'GENCODE__ENSG00000203783.5': 'TCONS_00003423',
#  'GENCODE__ENSG00000163220.11': 'TCONS_00000679',
#  'GENCODE__ENSG00000160679.14': 'TCONS_00003424',
#  'GENCODE__ENSG00000143553.11': 'TCONS_00003426',
#  'GENCODE__ENSG00000143624.14': 'TCONS_00006727',
#  'GENCODE__ENSG00000143554.14': 'TCONS_00003430',
#  'GENCODE__ENSG00000143578.16': 'TCONS_00006732',
#  'GENCODE__ENSG00000177954.14': 'TCONS_00000688',
#  'GENCODE__ENSG00000143575.16': 'TCONS_00003441',
#  'LOC101928120': 'TCONS_00003445',
#  'GENCODE__ENSG00000173207.13': 'TCONS_00000699',
#  'GENCODE__ENSG00000160688.19': 'TCONS_00003447',
#  'GENCODE__ENSG00000160685.14': 'TCONS_00000703',
#  'GENCODE__ENSG00000143537.14': 'TCONS_00000710',
#  'GENCODE__ENSG00000243364.8': 'TCONS_00000712',
#  'GENCODE__ENSG00000143590.14': 'TCONS_00003467',
#  'GENCODE__ENSG00000169242.12': 'TCONS_00003470',
#  'GENCODE__ENSG00000169241.19': 'TCONS_00003473',
#  'GENCODE__ENSG00000173171.15': 'TCONS_00000718',
#  'GENCODE__ENSG00000143630.10': 'TCONS_00000723',
#  'GENCODE__ENSG00000160752.15': 'TCONS_00003504',
#  'GENCODE__ENSG00000160753.17': 'TCONS_00000741',
#  'GENCODE__ENSG00000125459.18': 'TCONS_00003515',
#  'GENCODE__ENSG00000132676.16': 'TCONS_00003523',
#  'GENCODE__ENSG00000173080.6': 'TCONS_00003530',
#  'GENCODE__ENSG00000116586.12': 'TCONS_00000748',
#  'GENCODE__ENSG00000132698.15': 'TCONS_00000751',
#  'GENCODE__ENSG00000160789.25': 'TCONS_00000765',
#  'GENCODE__ENSG00000160785.14': 'TCONS_00003548',
#  'GENCODE__ENSG00000160783.19': 'TCONS_00003551',
#  'GENCODE__ENSG00000260238.6': 'TCONS_00000768',
#  'GENCODE__ENSG00000163472.19': 'TCONS_00003552',
#  'GENCODE__ENSG00000163382.13': 'TCONS_00000771',
#  'GENCODE__ENSG00000143303.12': 'TCONS_00003560',
#  'GENCODE__ENSG00000143294.15': 'TCONS_00000775',
#  'GENCODE__ENSG00000158481.13': 'TCONS_00006785',
#  'GENCODE__ENSG00000163563.8': 'TCONS_00003569',
#  'GENCODE__ENSG00000163565.20': 'TCONS_00006787',
#  'GENCODE__ENSG00000158716.9': 'TCONS_00000779',
#  'GENCODE__ENSG00000224259.9': 'TCONS_00000782',
#  'GENCODE__ENSG00000162734.13': 'TCONS_00003579',
#  'GENCODE__ENSG00000162736.18': 'TCONS_00010230',
#  'GENCODE__ENSG00000162755.14': 'TCONS_00006795',
#  'GENCODE__ENSG00000158793.14': 'TCONS_00003588',
#  'GENCODE__ENSG00000143222.12': 'TCONS_00000785',
#  'GENCODE__ENSG00000143224.18': 'TCONS_00003596',
#  'GENCODE__ENSG00000158864.13': 'TCONS_00006806',
#  'GENCODE__ENSG00000158869.11': 'TCONS_00003606',
#  'GENCODE__ENSG00000143252.17': 'TCONS_00003610',
#  'GENCODE__ENSG00000143226.16': 'TCONS_00003614',
#  'GENCODE__ENSG00000173110.8': 'TCONS_00003615',
#  'GENCODE__ENSG00000081721.12': 'TCONS_00003621',
#  'GENCODE__ENSG00000118217.7': 'TCONS_00000800',
#  'GENCODE__ENSG00000198929.13': 'TCONS_00000802',
#  'GENCODE__ENSG00000152332.16': 'TCONS_00003635',
#  'GENCODE__ENSG00000117143.14': 'TCONS_00006814',
#  'GENCODE__ENSG00000132196.16': 'TCONS_00000805',
#  'GENCODE__ENSG00000143228.13': 'TCONS_00006816',
#  'GENCODE__ENSG00000185630.20': 'TCONS_00003654',
#  'GENCODE__ENSG00000143198.13': 'TCONS_00003658',
#  'GENCODE__ENSG00000143179.16': 'TCONS_00003660',
#  'GENCODE__ENSG00000143157.12': 'TCONS_00006822',
#  'GENCODE__ENSG00000143190.23': 'TCONS_00008339',
#  'GENCODE__ENSG00000198771.11': 'TCONS_00003669',
#  'GENCODE__ENSG00000197965.12': 'TCONS_00000813',
#  'GENCODE__ENSG00000143164.16': 'TCONS_00008340',
#  'GENCODE__ENSG00000143155.13': 'TCONS_00003675',
#  'GENCODE__ENSG00000213064.10': 'TCONS_00000820',
#  'GENCODE__ENSG00000143153.14': 'TCONS_00000823',
#  'GENCODE__ENSG00000117475.14': 'TCONS_00003683',
#  'GENCODE__ENSG00000120370.14': 'TCONS_00003689',
#  'GENCODE__ENSG00000117523.18': 'TCONS_00000841',
#  'GENCODE__ENSG00000010165.20': 'TCONS_00003703',
#  'GENCODE__ENSG00000094975.15': 'TCONS_00003711',
#  'GENCODE__ENSG00000117592.9': 'TCONS_00000851',
#  'GENCODE__ENSG00000117593.12': 'TCONS_00003725',
#  'GENCODE__ENSG00000152061.24': 'TCONS_00003730',
#  'GENCODE__ENSG00000116161.18': 'TCONS_00000859',
#  'GENCODE__ENSG00000075391.18': 'TCONS_00003739',
#  'GENCODE__ENSG00000116191.19': 'TCONS_00008345',
#  'GENCODE__ENSG00000116199.12': 'TCONS_00003746',
#  'GENCODE__ENSG00000186283.14': 'TCONS_00011725',
#  'GENCODE__ENSG00000143337.19': 'TCONS_00003752',
#  'GENCODE__ENSG00000135837.18': 'TCONS_00000872',
#  'GENCODE__ENSG00000116260.17': 'TCONS_00000875',
#  'GENCODE__ENSG00000153029.16': 'TCONS_00003765',
#  'GENCODE__ENSG00000162783.11': 'TCONS_00003767',
#  'GENCODE__ENSG00000135838.14': 'TCONS_00003768',
#  'GENCODE__ENSG00000135829.17': 'TCONS_00003777',
#  'GENCODE__ENSG00000135862.6': 'TCONS_00003779',
#  'GENCODE__ENSG00000058085.15': 'TCONS_00000879',
#  'GENCODE__ENSG00000116698.22': 'TCONS_00003789',
#  'GENCODE__ENSG00000198860.14': 'TCONS_00000881',
#  'GENCODE__ENSG00000116667.15': 'TCONS_00000887',
#  'GENCODE__ENSG00000121481.12': 'TCONS_00003794',
#  'GENCODE__ENSG00000157181.16': 'TCONS_00010315',
#  'GENCODE__ENSG00000090104.12': 'TCONS_00003803',
#  'GENCODE__ENSG00000116741.8': 'TCONS_00003805',
#  'GENCODE__ENSG00000116747.13': 'TCONS_00000891',
#  'GENCODE__ENSG00000134371.15': 'TCONS_00003817',
#  'novelGene_RefSeq__LOC105371671_AS': 'TCONS_00000896',
#  'GENCODE__ENSG00000203724.11': 'TCONS_00000897',
#  'GENCODE__ENSG00000151414.15': 'TCONS_00003821',
#  'GENCODE__ENSG00000081237.21': 'TCONS_00003825',
#  'GENCODE__ENSG00000116833.14': 'TCONS_00010338',
#  'GENCODE__ENSG00000118200.15': 'TCONS_00003835',
#  'LOC101929343': 'TCONS_00000901',
#  'GENCODE__ENSG00000224536.2': 'TCONS_00000902',
#  'GENCODE__ENSG00000198700.10': 'TCONS_00003848',
#  'GENCODE__ENSG00000134375.11': 'TCONS_00006905',
#  'GENCODE__ENSG00000176393.11': 'TCONS_00006910',
#  'GENCODE__ENSG00000163435.16': 'TCONS_00000918',
#  'GENCODE__ENSG00000077157.23': 'TCONS_00006922',
#  'GENCODE__ENSG00000228288.9': 'TCONS_00000922',
#  'GENCODE__ENSG00000163444.12': 'TCONS_00003900',
#  'GENCODE__ENSG00000159388.6': 'TCONS_00000926',
#  'LINC00260': 'TCONS_00003904',
#  'GENCODE__ENSG00000257315.4': 'TCONS_00003908',
#  'GENCODE__ENSG00000058673.17': 'TCONS_00000931',
#  'GENCODE__ENSG00000182004.13': 'TCONS_00000932',
#  'GENCODE__ENSG00000198625.14': 'TCONS_00003931',
#  'GENCODE__ENSG00000117266.16': 'TCONS_00006934',
#  'GENCODE__ENSG00000266028.8': 'TCONS_00000938',
#  'GENCODE__ENSG00000263528.8': 'TCONS_00000940',
#  'GENCODE__ENSG00000266094.8': 'TCONS_00003938',
#  'GENCODE__ENSG00000162889.11': 'TCONS_00006942',
#  'GENCODE__ENSG00000123836.15': 'TCONS_00006943',
#  'GENCODE__ENSG00000123843.13': 'TCONS_00003942',
#  'GENCODE__ENSG00000196352.18': 'TCONS_00003947',
#  'GENCODE__ENSG00000117335.21': 'TCONS_00003964',
#  'GENCODE__ENSG00000123689.6': 'TCONS_00000952',
#  'GENCODE__ENSG00000009790.15': 'TCONS_00009235',
#  'GENCODE__ENSG00000117597.18': 'TCONS_00003976',
#  'GENCODE__ENSG00000117625.14': 'TCONS_00003990',
#  'GENCODE__ENSG00000082512.15': 'TCONS_00000959',
#  'GENCODE__ENSG00000066027.12': 'TCONS_00000966',
#  'GENCODE__ENSG00000117691.10': 'TCONS_00000967',
#  'GENCODE__ENSG00000162772.18': 'TCONS_00010394',
#  'GENCODE__ENSG00000203705.11': 'TCONS_00004012',
#  'GENCODE__ENSG00000162769.13': 'TCONS_00004014',
#  'GENCODE__ENSG00000117707.17': 'TCONS_00004021',
#  'GENCODE__ENSG00000117724.15': 'TCONS_00011789',
#  'GENCODE__ENSG00000136636.13': 'TCONS_00000985',
#  'GENCODE__ENSG00000067533.6': 'TCONS_00006964',
#  'GENCODE__ENSG00000143353.12': 'TCONS_00000987',
#  'GENCODE__ENSG00000067704.10': 'TCONS_00010405',
#  'GENCODE__ENSG00000162817.7': 'TCONS_00000993',
#  'GENCODE__ENSG00000186205.14': 'TCONS_00004056',
#  'GENCODE__ENSG00000154305.18': 'TCONS_00000995',
#  'GENCODE__ENSG00000162819.12': 'TCONS_00000998',
#  'GENCODE__ENSG00000162909.18': 'TCONS_00004072',
#  'GENCODE__ENSG00000290989.1': 'TCONS_00004073',
#  'GENCODE__ENSG00000143756.12': 'TCONS_00004075',
#  'GENCODE__ENSG00000143753.14': 'TCONS_00004079',
#  'GENCODE__ENSG00000143771.12': 'TCONS_00001003',
#  'GENCODE__ENSG00000185842.16': 'TCONS_00008416',
#  'GENCODE__ENSG00000143742.14': 'TCONS_00001011',
#  'GENCODE__ENSG00000143819.13': 'TCONS_00004092',
#  'GENCODE__ENSG00000163041.13': 'TCONS_00001014',
#  'GENCODE__ENSG00000143801.18': 'TCONS_00004095',
#  'GENCODE__ENSG00000163050.18': 'TCONS_00011821',
#  'GENCODE__ENSG00000143740.15': 'TCONS_00004106',
#  'GENCODE__ENSG00000143761.17': 'TCONS_00004109',
#  'GENCODE__ENSG00000143774.18': 'TCONS_00001044',
#  'GENCODE__ENSG00000198835.4': 'TCONS_00004122',
#  'GENCODE__ENSG00000181873.13': 'TCONS_00006994',
#  'GENCODE__ENSG00000154358.23': 'TCONS_00011836',
#  'GENCODE__ENSG00000168159.15': 'TCONS_00001045',
#  'GENCODE__ENSG00000116574.6': 'TCONS_00004126',
#  'GENCODE__ENSG00000168118.12': 'TCONS_00004132',
#  'GENCODE__ENSG00000135763.10': 'TCONS_00004137',
#  'GENCODE__ENSG00000143641.10': 'TCONS_00007000',
#  'RefSeq__LOC124904544': 'TCONS_00007001',
#  'GENCODE__ENSG00000135775.14': 'TCONS_00008430',
#  'GENCODE__ENSG00000173409.14': 'TCONS_00001052',
#  'GENCODE__ENSG00000116906.13': 'TCONS_00004154',
#  'GENCODE__ENSG00000010072.16': 'TCONS_00001055',
#  'GENCODE__ENSG00000116918.15': 'TCONS_00001057',
#  'GENCODE__ENSG00000135778.12': 'TCONS_00007012',
#  'GENCODE__ENSG00000143674.11': 'TCONS_00004161',
#  'GENCODE__ENSG00000135750.15': 'TCONS_00008440',
#  'GENCODE__ENSG00000168275.16': 'TCONS_00004163',
#  'GENCODE__ENSG00000152904.11': 'TCONS_00001067',
#  'GENCODE__ENSG00000284770.2': 'TCONS_00004165',
#  'GENCODE__ENSG00000116977.19': 'TCONS_00004172',
#  'GENCODE__ENSG00000116984.15': 'TCONS_00001071',
#  'GENCODE__ENSG00000174371.17': 'TCONS_00007022',
#  'GENCODE__ENSG00000179456.12': 'TCONS_00004194',
#  'GENCODE__ENSG00000121644.19': 'TCONS_00001081',
#  'GENCODE__ENSG00000203667.10': 'TCONS_00004198',
#  'GENCODE__ENSG00000203666.13': 'TCONS_00007028',
#  'GENCODE__ENSG00000162852.14': 'TCONS_00007029',
#  'GENCODE__ENSG00000143653.10': 'TCONS_00001088',
#  'GENCODE__ENSG00000171161.13': 'TCONS_00004206',
#  'GENCODE__ENSG00000227232.6': 'TCONS_00001093',
#  'GENCODE__ENSG00000279457.4': 'TCONS_00004209',
#  'GENCODE__ENSG00000225880.6___GENCODE__ENSG00000290784.1': 'TCONS_00004212',
#  'GENCODE__ENSG00000225880.6': 'TCONS_00001098',
#  'GENCODE__ENSG00000188976.11': 'TCONS_00001105',
#  'GENCODE__ENSG00000188290.11': 'TCONS_00004220',
#  'GENCODE__ENSG00000131591.18': 'TCONS_00010473',
#  'GENCODE__ENSG00000186891.14': 'TCONS_00001107',
#  'GENCODE__ENSG00000186827.12': 'TCONS_00001108',
#  'GENCODE__ENSG00000078808.20': 'TCONS_00001114',
#  'GENCODE__ENSG00000184163.3': 'TCONS_00001116',
#  'GENCODE__ENSG00000160087.21': 'TCONS_00004240',
#  'GENCODE__ENSG00000131584.19': 'TCONS_00007054',
#  'GENCODE__ENSG00000127054.22': 'TCONS_00001123',
#  'GENCODE__ENSG00000107404.21': 'TCONS_00008471',
#  'GENCODE__ENSG00000175756.14': 'TCONS_00004251',
#  'GENCODE__ENSG00000221978.13': 'TCONS_00001137',
#  'GENCODE__ENSG00000242485.6': 'TCONS_00004257',
#  'GENCODE__ENSG00000160075.12': 'TCONS_00001143',
#  'GENCODE__ENSG00000272106.1': 'TCONS_00004260',
#  'GENCODE__ENSG00000248333.9': 'TCONS_00001155',
#  'GENCODE__ENSG00000189339.12': 'TCONS_00001159',
#  'GENCODE__ENSG00000008128.23': 'TCONS_00001167',
#  'GENCODE__ENSG00000008130.15': 'TCONS_00004273',
#  'GENCODE__ENSG00000078369.19': 'TCONS_00007077',
#  'GENCODE__ENSG00000178821.13': 'TCONS_00004285',
#  'GENCODE__ENSG00000162585.17': 'TCONS_00001177',
#  'GENCODE__ENSG00000157911.11': 'TCONS_00001183',
#  'GENCODE__ENSG00000197921.6': 'TCONS_00007082',
#  'LOC105378604': 'TCONS_00001190',
#  'GENCODE__ENSG00000287828.1': 'TCONS_00004292',
#  'GENCODE__ENSG00000116213.16': 'TCONS_00004298',
#  'GENCODE__ENSG00000130764.10': 'TCONS_00007093',
#  'GENCODE__ENSG00000116198.14': 'TCONS_00004302',
#  'GENCODE__ENSG00000198912.12': 'TCONS_00001198',
#  'GENCODE__ENSG00000116251.11': 'TCONS_00001202',
#  'GENCODE__ENSG00000116237.16': 'TCONS_00004305',
#  'GENCODE__ENSG00000097021.21': 'TCONS_00009284',
#  'GENCODE__ENSG00000215788.11': 'TCONS_00007105',
#  'GENCODE__ENSG00000171680.23': 'TCONS_00004312',
#  'GENCODE__ENSG00000162408.11': 'TCONS_00010527',
#  'GENCODE__ENSG00000007923.17': 'TCONS_00004319',
#  'GENCODE__ENSG00000116285.13': 'TCONS_00001214',
#  'GENCODE__ENSG00000142599.20': 'TCONS_00004329',
#  'GENCODE__ENSG00000074800.16': 'TCONS_00001229',
#  'GENCODE__ENSG00000142583.18': 'TCONS_00007111',
#  'GENCODE__ENSG00000171603.18': 'TCONS_00004340',
#  'GENCODE__ENSG00000178585.15': 'TCONS_00004343',
#  'GENCODE__ENSG00000162441.12': 'TCONS_00007116',
#  'GENCODE__ENSG00000160049.12': 'TCONS_00001234',
#  'GENCODE__ENSG00000130940.15': 'TCONS_00001235',
#  'GENCODE__ENSG00000116649.10': 'TCONS_00001237',
#  'GENCODE__ENSG00000171824.14': 'TCONS_00001241',
#  'GENCODE__ENSG00000198793.14': 'TCONS_00001242',
#  'GENCODE__ENSG00000116661.11': 'TCONS_00001245',
#  'GENCODE__ENSG00000116670.16': 'TCONS_00001249',
#  'GENCODE__ENSG00000116685.17': 'TCONS_00001251',
#  'GENCODE__ENSG00000162496.10': 'TCONS_00004358',
#  'GENCODE__ENSG00000132906.18': 'TCONS_00004362',
#  'GENCODE__ENSG00000116771.6': 'TCONS_00001254',
#  'GENCODE__ENSG00000116809.12': 'TCONS_00004366',
#  'GENCODE__ENSG00000142627.13': 'TCONS_00004367',
#  'GENCODE__ENSG00000142632.17': 'TCONS_00004371',
#  'GENCODE__ENSG00000291077.1': 'TCONS_00001261',
#  'GENCODE__ENSG00000037637.11': 'TCONS_00004376',
#  'GENCODE__ENSG00000219481.11': 'TCONS_00004379',
#  'GENCODE__ENSG00000291072.2': 'TCONS_00004380',
#  'GENCODE__ENSG00000290851.1': 'TCONS_00007149',
#  'GENCODE__ENSG00000238142.4': 'TCONS_00001266',
#  'GENCODE__ENSG00000159363.19': 'TCONS_00008519',
#  'GENCODE__ENSG00000117118.12': 'TCONS_00001274',
#  'GENCODE__ENSG00000117115.13': 'TCONS_00007154',
#  'GENCODE__ENSG00000159423.17': 'TCONS_00004392',
#  'GENCODE__ENSG00000169991.11': 'TCONS_00004393',
#  'GENCODE__ENSG00000127481.15': 'TCONS_00004397',
#  'GENCODE__ENSG00000127463.16': 'TCONS_00004403',
#  'GENCODE__ENSG00000162482.5': 'TCONS_00004407',
#  'GENCODE__ENSG00000053371.13': 'TCONS_00001291',
#  'GENCODE__ENSG00000077549.19': 'TCONS_00001297',
#  'GENCODE__ENSG00000162542.14': 'TCONS_00004414',
#  'GENCODE__ENSG00000178828.7': 'TCONS_00001300',
#  'GENCODE__ENSG00000188257.12': 'TCONS_00010582',
#  'GENCODE__ENSG00000162545.6___GENCODE__ENSG00000289402.2': 'TCONS_00001303',
#  'GENCODE__ENSG00000090432.7': 'TCONS_00004419',
#  'GENCODE__ENSG00000244038.11': 'TCONS_00009309',
#  'GENCODE__ENSG00000127483.19': 'TCONS_00001313',
#  'GENCODE__ENSG00000075151.24': 'TCONS_00007179',
#  'GENCODE__ENSG00000076864.21': 'TCONS_00007183',
#  'GENCODE__ENSG00000090686.16': 'TCONS_00001320',
#  'GENCODE__ENSG00000162552.15': 'TCONS_00007191',
#  'GENCODE__ENSG00000169641.16': 'TCONS_00004465',
#  'GENCODE__ENSG00000125944.22': 'TCONS_00004481',
#  'GENCODE__ENSG00000204219.11': 'TCONS_00007199',
#  'GENCODE__ENSG00000117318.9': 'TCONS_00007202',
#  'GENCODE__ENSG00000117308.15': 'TCONS_00001343',
#  'GENCODE__ENSG00000117305.15': 'TCONS_00004492',
#  'GENCODE__ENSG00000179163.12': 'TCONS_00001350',
#  'GENCODE__ENSG00000188529.15': 'TCONS_00001355',
#  'GENCODE__ENSG00000117614.10': 'TCONS_00001361',
#  'GENCODE__ENSG00000117616.18': 'TCONS_00001368',
#  'GENCODE__ENSG00000127423.11': 'TCONS_00004506',
#  'GENCODE__ENSG00000117632.23': 'TCONS_00001371',
#  'GENCODE__ENSG00000158062.21': 'TCONS_00001374',
#  'GENCODE__ENSG00000142751.15': 'TCONS_00004511',
#  'GENCODE__ENSG00000198746.13': 'TCONS_00004512',
#  'GENCODE__ENSG00000131910.5': 'TCONS_00001379',
#  'GENCODE__ENSG00000175707.10': 'TCONS_00004514',
#  'GENCODE__ENSG00000142733.18': 'TCONS_00001381',
#  'GENCODE__ENSG00000158195.11': 'TCONS_00001385',
#  'GENCODE__ENSG00000126705.15': 'TCONS_00001386',
#  'GENCODE__ENSG00000126709.16': 'TCONS_00001387',
#  'GENCODE__ENSG00000117748.10': 'TCONS_00004519',
#  'GENCODE__ENSG00000126698.11': 'TCONS_00001391',
#  'GENCODE__ENSG00000290123.1___GENCODE__ENSG00000126698.11': 'TCONS_00007226',
#  'GENCODE__ENSG00000290123.1': 'TCONS_00007228',
#  'GENCODE__ENSG00000197989.15': 'TCONS_00007232',
#  'GENCODE__ENSG00000120656.14': 'TCONS_00001395',
#  'GENCODE__ENSG00000116350.18': 'TCONS_00001400',
#  'GENCODE__ENSG00000116353.16': 'TCONS_00004532',
#  'GENCODE__ENSG00000162511.8': 'TCONS_00001402',
#  'GENCODE__ENSG00000134644.16': 'TCONS_00001414',
#  'novelGene_16': 'TCONS_00004538',
#  'GENCODE__ENSG00000060688.13': 'TCONS_00004542',
#  'GENCODE__ENSG00000162517.13': 'TCONS_00010644',
#  'GENCODE__ENSG00000084636.18': 'TCONS_00010645',
#  'GENCODE__ENSG00000184007.22': 'TCONS_00004557',
#  'GENCODE__ENSG00000160055.20': 'TCONS_00004559',
#  'GENCODE__ENSG00000291132.1': 'TCONS_00007244',
#  'GENCODE__ENSG00000175130.7': 'TCONS_00004562',
#  'GENCODE__ENSG00000225828.2': 'TCONS_00007245',
#  'GENCODE__ENSG00000160058.19': 'TCONS_00001421',
#  'GENCODE__ENSG00000176261.16': 'TCONS_00001426',
#  'GENCODE__ENSG00000134684.13': 'TCONS_00001430',
#  'GENCODE__ENSG00000121900.19': 'TCONS_00001432',
#  'GENCODE__ENSG00000116514.17': 'TCONS_00001439',
#  'GENCODE__ENSG00000004455.18': 'TCONS_00001443',
#  'GENCODE__ENSG00000134686.21': 'TCONS_00001446',
#  'GENCODE__ENSG00000163866.9': 'TCONS_00001448',
#  'GENCODE__ENSG00000243749.2': 'TCONS_00004591',
#  'GENCODE__ENSG00000116560.12': 'TCONS_00004598',
#  'GENCODE__ENSG00000142687.19': 'TCONS_00004599',
#  'GENCODE__ENSG00000126067.12': 'TCONS_00001457',
#  'GENCODE__ENSG00000092853.14': 'TCONS_00001461',
#  'GENCODE__ENSG00000054116.12': 'TCONS_00001463',
#  'GENCODE__ENSG00000142694.7': 'TCONS_00001465',
#  'GENCODE__ENSG00000181817.6': 'TCONS_00001466',
#  'GENCODE__ENSG00000116898.12': 'TCONS_00008599',
#  'GENCODE__ENSG00000233621.3': 'TCONS_00008600',
#  'GENCODE__ENSG00000163875.16': 'TCONS_00001471',
#  'GENCODE__ENSG00000163877.11': 'TCONS_00001473',
#  'GENCODE__ENSG00000134697.13': 'TCONS_00001475',
#  'GENCODE__ENSG00000116922.15': 'TCONS_00004629',
#  'GENCODE__ENSG00000196449.4': 'TCONS_00004631',
#  'GENCODE__ENSG00000204084.14': 'TCONS_00004633',
#  'GENCODE__ENSG00000183431.12': 'TCONS_00001481',
#  'GENCODE__ENSG00000183386.10': 'TCONS_00004638',
#  'GENCODE__ENSG00000116954.8': 'TCONS_00004639',
#  'GENCODE__ENSG00000214114.9': 'TCONS_00001484',
#  'GENCODE__ENSG00000158315.11': 'TCONS_00004640',
#  'GENCODE__ENSG00000090621.15': 'TCONS_00001490',
#  'GENCODE__ENSG00000116985.12': 'TCONS_00004654',
#  'GENCODE__ENSG00000116990.12': 'TCONS_00004662',
#  'GENCODE__ENSG00000131238.18': 'TCONS_00004663',
#  'GENCODE__ENSG00000259943.2': 'TCONS_00004665',
#  'GENCODE__ENSG00000049089.15': 'TCONS_00007301',
#  'GENCODE__ENSG00000272145.2': 'TCONS_00004666',
#  'GENCODE__ENSG00000179862.7': 'TCONS_00001496',
#  'GENCODE__ENSG00000010803.17': 'TCONS_00010699',
#  'GENCODE__ENSG00000127129.10': 'TCONS_00008612',
#  'GENCODE__ENSG00000197273.4': 'TCONS_00010700',
#  'GENCODE__ENSG00000177868.12': 'TCONS_00001498',
#  'GENCODE__ENSG00000117394.24': 'TCONS_00007311',
#  'GENCODE__ENSG00000117395.13': 'TCONS_00001505',
#  'GENCODE__ENSG00000253313.6': 'TCONS_00012015',
#  'GENCODE__ENSG00000066322.15': 'TCONS_00004683',
#  'GENCODE__ENSG00000159479.17': 'TCONS_00007316',
#  'GENCODE__ENSG00000178922.18': 'TCONS_00004692',
#  'GENCODE__ENSG00000117419.16': 'TCONS_00001523',
#  'GENCODE__ENSG00000126106.14': 'TCONS_00001525',
#  'GENCODE__ENSG00000142959.5': 'TCONS_00010711',
#  'GENCODE__ENSG00000070785.17': 'TCONS_00004699',
#  'GENCODE__ENSG00000126107.15': 'TCONS_00008618',
#  'GENCODE__ENSG00000132781.22': 'TCONS_00004703',
#  'GENCODE__ENSG00000117450.15': 'TCONS_00004707',
#  'GENCODE__ENSG00000159592.11': 'TCONS_00001539',
#  'GENCODE__ENSG00000225447.1': 'TCONS_00010718',
#  'GENCODE__ENSG00000197429.11': 'TCONS_00001542',
#  'GENCODE__ENSG00000085998.15': 'TCONS_00004719',
#  'GENCODE__ENSG00000132128.18': 'TCONS_00012032',
#  'GENCODE__ENSG00000079277.22': 'TCONS_00001547',
#  'GENCODE__ENSG00000142961.16': 'TCONS_00004727',
#  'GENCODE__ENSG00000123472.13': 'TCONS_00001549',
#  'GENCODE__ENSG00000159658.15': 'TCONS_00001552',
#  'GENCODE__ENSG00000162366.8': 'TCONS_00008636',
#  'GENCODE__ENSG00000225762.1': 'TCONS_00004740',
#  'GENCODE__ENSG00000237424.1': 'TCONS_00004742',
#  'RefSeq__LOC124904174': 'TCONS_00008640',
#  'GENCODE__ENSG00000132122.12': 'TCONS_00004743',
#  'GENCODE__ENSG00000162373.13': 'TCONS_00007372',
#  'GENCODE__ENSG00000185104.21': 'TCONS_00007374',
#  'GENCODE__ENSG00000085831.16': 'TCONS_00009362',
#  'GENCODE__ENSG00000085832.18': 'TCONS_00004755',
#  'GENCODE__ENSG00000078618.23': 'TCONS_00001565',
#  'GENCODE__ENSG00000117862.14': 'TCONS_00001567',
#  'GENCODE__ENSG00000198841.4': 'TCONS_00004770',
#  'GENCODE__ENSG00000085840.13': 'TCONS_00004773',
#  'GENCODE__ENSG00000134744.14': 'TCONS_00001576',
#  'GENCODE__ENSG00000162377.6': 'TCONS_00001577',
#  'GENCODE__ENSG00000121310.17': 'TCONS_00001582',
#  'GENCODE__ENSG00000162384.14': 'TCONS_00001583',
#  'GENCODE__ENSG00000162385.11': 'TCONS_00001585',
#  'GENCODE__ENSG00000157193.18': 'TCONS_00004785',
#  'GENCODE__ENSG00000058799.15': 'TCONS_00004791',
#  'GENCODE__ENSG00000081870.12': 'TCONS_00007396',
#  'GENCODE__ENSG00000116209.12': 'TCONS_00004798',
#  'GENCODE__ENSG00000157216.17': 'TCONS_00012071',
#  'GENCODE__ENSG00000162396.6': 'TCONS_00001596',
#  'GENCODE__ENSG00000116133.13': 'TCONS_00001601',
#  'GENCODE__ENSG00000162402.15': 'TCONS_00001603',
#  'GENCODE__ENSG00000162407.9': 'TCONS_00001604',
#  'GENCODE__ENSG00000162600.12': 'TCONS_00004822',
#  'GENCODE__ENSG00000184292.7': 'TCONS_00004823',
#  'GENCODE__ENSG00000162601.12': 'TCONS_00004828',
#  'GENCODE__ENSG00000177606.9': 'TCONS_00004831',
#  'GENCODE__ENSG00000134716.11': 'TCONS_00004834',
#  'GENCODE__ENSG00000116641.18': 'TCONS_00007418',
#  'GENCODE__ENSG00000142856.17': 'TCONS_00007419',
#  'GENCODE__ENSG00000162434.14': 'TCONS_00004852',
#  'GENCODE__ENSG00000172410.5': 'TCONS_00007422',
#  'GENCODE__ENSG00000116704.8': 'TCONS_00001627',
#  'GENCODE__ENSG00000142864.15': 'TCONS_00001647',
#  'GENCODE__ENSG00000172380.6': 'TCONS_00004863',
#  'GENCODE__ENSG00000116729.14': 'TCONS_00001653',
#  'GENCODE__ENSG00000234383.1': 'TCONS_00001652',
#  'GENCODE__ENSG00000024526.17': 'TCONS_00012094',
#  'GENCODE__ENSG00000066557.6': 'TCONS_00007429',
#  'GENCODE__ENSG00000118454.13': 'TCONS_00004875',
#  'GENCODE__ENSG00000132485.14': 'TCONS_00004879',
#  'GENCODE__ENSG00000116791.14': 'TCONS_00001657',
#  'GENCODE__ENSG00000142892.15': 'TCONS_00004883',
#  'GENCODE__ENSG00000036549.13': 'TCONS_00004889',
#  'GENCODE__ENSG00000077254.14': 'TCONS_00004897',
#  'GENCODE__ENSG00000162613.18': 'TCONS_00001661',
#  'GENCODE__ENSG00000174021.12': 'TCONS_00001663',
#  'GENCODE__ENSG00000117151.13___GENCODE__ENSG00000174021.12': 'TCONS_00004904',
#  'GENCODE__ENSG00000117151.13': 'TCONS_00004905',
#  'GENCODE__ENSG00000117155.17': 'TCONS_00004915',
#  'GENCODE__ENSG00000153898.13': 'TCONS_00009392',
#  'GENCODE__ENSG00000055732.13': 'TCONS_00004916',
#  'GENCODE__ENSG00000097096.10': 'TCONS_00004921',
#  'GENCODE__ENSG00000162642.14': 'TCONS_00001666',
#  'GENCODE__ENSG00000142867.14': 'TCONS_00007460',
#  'GENCODE__ENSG00000153904.21': 'TCONS_00004928',
#  'GENCODE__ENSG00000117174.11': 'TCONS_00007463',
#  'GENCODE__ENSG00000122417.16': 'TCONS_00007466',
#  'GENCODE__ENSG00000183291.18': 'TCONS_00004939',
#  'GENCODE__ENSG00000137947.12': 'TCONS_00004940',
#  'GENCODE__ENSG00000137944.18': 'TCONS_00004942',
#  'GENCODE__ENSG00000213516.10': 'TCONS_00004947',
#  'GENCODE__ENSG00000117226.12': 'TCONS_00001675',
#  'GENCODE__ENSG00000117228.11': 'TCONS_00004954',
#  'GENCODE__ENSG00000162645.13': 'TCONS_00004958',
#  'GENCODE__ENSG00000154451.15': 'TCONS_00008688',
#  'GENCODE__ENSG00000272931.1': 'TCONS_00004965',
#  'GENCODE__ENSG00000122482.22': 'TCONS_00004970',
#  'GENCODE__ENSG00000174842.17': 'TCONS_00009406',
#  'GENCODE__ENSG00000067208.17': 'TCONS_00004978',
#  'GENCODE__ENSG00000154511.12': 'TCONS_00004979',
#  'GENCODE__ENSG00000117500.13': 'TCONS_00001686',
#  'GENCODE__ENSG00000223745.8': 'TCONS_00001688',
#  'GENCODE__ENSG00000137936.18': 'TCONS_00004983',
#  'GENCODE__ENSG00000067334.14': 'TCONS_00001690',
#  'GENCODE__ENSG00000023909.10': 'TCONS_00004989',
#  'GENCODE__ENSG00000117525.14': 'TCONS_00007492',
#  'GENCODE__ENSG00000117519.16': 'TCONS_00001693',
#  'GENCODE__ENSG00000172339.10': 'TCONS_00004998',
#  'GENCODE__ENSG00000137970.7': 'TCONS_00001694',
#  'GENCODE__ENSG00000162694.14': 'TCONS_00005013',
#  'GENCODE__ENSG00000117543.22': 'TCONS_00005014',
#  'GENCODE__ENSG00000134215.16': 'TCONS_00007505',
#  'GENCODE__ENSG00000085491.17': 'TCONS_00001701',
#  'GENCODE__ENSG00000162639.16': 'TCONS_00005025',
#  'GENCODE__ENSG00000121940.17': 'TCONS_00005028',
#  'GENCODE__ENSG00000197780.11': 'TCONS_00009417',
#  'GENCODE__ENSG00000273382.1': 'TCONS_00005032',
#  'GENCODE__ENSG00000134222.16': 'TCONS_00005033',
#  'GENCODE__ENSG00000134243.12': 'TCONS_00007518',
#  'GENCODE__ENSG00000143106.13': 'TCONS_00005042',
#  'GENCODE__ENSG00000134202.12': 'TCONS_00001708',
#  'GENCODE__ENSG00000198758.11': 'TCONS_00001714',
#  'GENCODE__ENSG00000134248.14': 'TCONS_00001715',
#  'GENCODE__ENSG00000121931.16': 'TCONS_00001719',
#  'GENCODE__ENSG00000156171.15': 'TCONS_00005061',
#  'GENCODE__ENSG00000162777.17': 'TCONS_00005068',
#  'GENCODE__ENSG00000116455.14': 'TCONS_00008714',
#  'GENCODE__ENSG00000197852.12': 'TCONS_00001724',
#  'GENCODE__ENSG00000155366.17': 'TCONS_00005078',
#  'GENCODE__ENSG00000155367.16': 'TCONS_00005081',
#  'GENCODE__ENSG00000155380.13': 'TCONS_00001732',
#  'GENCODE__ENSG00000081019.14': 'TCONS_00001736',
#  'GENCODE__ENSG00000134242.16': 'TCONS_00005093',
#  'GENCODE__ENSG00000188761.13': 'TCONS_00001738',
#  'GENCODE__ENSG00000134262.15': 'TCONS_00005097',
#  'GENCODE__ENSG00000197323.12': 'TCONS_00005104',
#  'GENCODE__ENSG00000116752.6': 'TCONS_00001740',
#  'GENCODE__ENSG00000213281.5': 'TCONS_00005109',
#  'GENCODE__ENSG00000009307.17': 'TCONS_00001744',
#  'GENCODE__ENSG00000052723.12': 'TCONS_00005132',
#  'GENCODE__ENSG00000116815.16': 'TCONS_00001750',
#  'GENCODE__ENSG00000177173.5': 'TCONS_00005135',
#  'GENCODE__ENSG00000116874.12': 'TCONS_00001753',
#  'GENCODE__ENSG00000134240.12': 'TCONS_00007561',
#  'GENCODE__ENSG00000134193.15': 'TCONS_00010907',
#  'GENCODE__ENSG00000265808.4': 'TCONS_00001758',
#  'GENCODE__ENSG00000290569.1': 'TCONS_00007569',
#  'GENCODE__ENSG00000265491.5': 'TCONS_00005164',
#  'GENCODE__ENSG00000131779.11': 'TCONS_00005170',
#  'GENCODE__ENSG00000265241.8': 'TCONS_00001777',
#  'GENCODE__ENSG00000271601.4': 'TCONS_00005176',
#  'GENCODE__ENSG00000265972.6': 'TCONS_00001781',
#  'GENCODE__ENSG00000271425.9': 'TCONS_00009449',
#  'RefSeq__LOC124904401___GENCODE__ENSG00000264343.7': 'TCONS_00010927',
#  'GENCODE__ENSG00000264343.7': 'TCONS_00010930',
#  'GENCODE__ENSG00000131781.13': 'TCONS_00007602',
#  'GENCODE__ENSG00000226015.2': 'TCONS_00005192',
#  'GENCODE__ENSG00000162836.12': 'TCONS_00005193',
#  'GENCODE__ENSG00000270629.7': 'TCONS_00001796',
#  'GENCODE__ENSG00000269713.9': 'TCONS_00007617',
#  'GENCODE__ENSG00000203814.7': 'TCONS_00001803',
#  'GENCODE__ENSG00000183598.4': 'TCONS_00005211',
#  'GENCODE__ENSG00000203811.2': 'TCONS_00001804',
#  'GENCODE__ENSG00000288825.1': 'TCONS_00001806',
#  'GENCODE__ENSG00000290792.1': 'TCONS_00005213',
#  'GENCODE__ENSG00000261716.3': 'TCONS_00005217',
#  'GENCODE__ENSG00000270276.3': 'TCONS_00005220',
#  'GENCODE__ENSG00000184678.11': 'TCONS_00005221',
#  'GENCODE__ENSG00000184270.6': 'TCONS_00001811',
#  'GENCODE__ENSG00000143368.10': 'TCONS_00001812',
#  'GENCODE__ENSG00000014914.21': 'TCONS_00010947',
#  'GENCODE__ENSG00000143401.15': 'TCONS_00001817',
#  'GENCODE__ENSG00000117362.13': 'TCONS_00005234',
#  'RefSeq__LOC124904414___GENCODE__ENSG00000117362.13': 'TCONS_00005230',
#  'GENCODE__ENSG00000143384.14': 'TCONS_00001820',
#  'GENCODE__ENSG00000143420.19': 'TCONS_00001824',
#  'GENCODE__ENSG00000143457.11': 'TCONS_00001825',
#  'GENCODE__ENSG00000163131.12': 'TCONS_00001827',
#  'GENCODE__ENSG00000143418.20': 'TCONS_00005263',
#  'GENCODE__ENSG00000143409.18': 'TCONS_00005264',
#  'GENCODE__ENSG00000197622.13': 'TCONS_00001830',
#  'GENCODE__ENSG00000163159.15___GENCODE__ENSG00000163157.15': 'TCONS_00001832',
#  'GENCODE__ENSG00000143393.17': 'TCONS_00001834',
#  'GENCODE__ENSG00000143416.21': 'TCONS_00005271',
#  'GENCODE__ENSG00000143442.24': 'TCONS_00005289',
#  'GENCODE__ENSG00000143436.11': 'TCONS_00001844',
#  'GENCODE__ENSG00000143365.20': 'TCONS_00005301',
#  'GENCODE__ENSG00000225556.2': 'TCONS_00005303',
#  'GENCODE__ENSG00000159445.13': 'TCONS_00001845',
#  'GENCODE__ENSG00000197747.9': 'TCONS_00001848',
#  'GENCODE__ENSG00000163191.6': 'TCONS_00005309',
#  'GENCODE__ENSG00000143546.10': 'TCONS_00005311',
#  'GENCODE__ENSG00000197956.10': 'TCONS_00001854',
#  'GENCODE__ENSG00000196154.12': 'TCONS_00008773',
#  'GENCODE__ENSG00000188643.11': 'TCONS_00012241',
#  'GENCODE__ENSG00000189334.9': 'TCONS_00010993',
#  'GENCODE__ENSG00000189171.15': 'TCONS_00001864',
#  'GENCODE__ENSG00000143621.17': 'TCONS_00001867',
#  'GENCODE__ENSG00000143614.11': 'TCONS_00005323',
#  'GENCODE__ENSG00000223599.1': 'TCONS_00005325',
#  'GENCODE__ENSG00000198837.10': 'TCONS_00005326',
#  'GENCODE__ENSG00000143570.19': 'TCONS_00001871',
#  'GENCODE__ENSG00000143543.15': 'TCONS_00007671',
#  'GENCODE__ENSG00000143545.10': 'TCONS_00001875',
#  'GENCODE__ENSG00000143549.22': 'TCONS_00001886',
#  'GENCODE__ENSG00000143612.21': 'TCONS_00005342',
#  'GENCODE__ENSG00000160714.10': 'TCONS_00001889',
#  'GENCODE__ENSG00000160710.19': 'TCONS_00001895',
#  'GENCODE__ENSG00000143603.19': 'TCONS_00008784',
#  'GENCODE__ENSG00000163344.6': 'TCONS_00007683',
#  'GENCODE__ENSG00000163346.17': 'TCONS_00001901',
#  'GENCODE__ENSG00000160691.19': 'TCONS_00005364',
#  'GENCODE__ENSG00000179085.8': 'TCONS_00005372',
#  'GENCODE__ENSG00000163463.13': 'TCONS_00001905',
#  'GENCODE__ENSG00000185499.17': 'TCONS_00012265',
#  'GENCODE__ENSG00000291137.1': 'TCONS_00001910',
#  'GENCODE__ENSG00000177628.16': 'TCONS_00007690',
#  'GENCODE__ENSG00000160767.23': 'TCONS_00005381',
#  'GENCODE__ENSG00000116521.12': 'TCONS_00001914',
#  'GENCODE__ENSG00000176444.19': 'TCONS_00001917',
#  'GENCODE__ENSG00000116539.14': 'TCONS_00001920',
#  'GENCODE__ENSG00000163374.21': 'TCONS_00008796',
#  'GENCODE__ENSG00000116580.20': 'TCONS_00005406',
#  'GENCODE__ENSG00000143622.12': 'TCONS_00001922',
#  'GENCODE__ENSG00000132680.11': 'TCONS_00005411',
#  'GENCODE__ENSG00000116584.22': 'TCONS_00001925',
#  'GENCODE__ENSG00000163479.14': 'TCONS_00005422',
#  'GENCODE__ENSG00000160803.8': 'TCONS_00005423',
#  'GENCODE__ENSG00000198952.8': 'TCONS_00001929',
#  'GENCODE__ENSG00000198715.13': 'TCONS_00007707',
#  'GENCODE__ENSG00000163468.15': 'TCONS_00001939',
#  'GENCODE__ENSG00000116604.19': 'TCONS_00005441',
#  'GENCODE__ENSG00000183856.11': 'TCONS_00005442',
#  'GENCODE__ENSG00000160818.17': 'TCONS_00001944',
#  'GENCODE__ENSG00000272405.1': 'TCONS_00001950',
#  'GENCODE__ENSG00000229953.1': 'TCONS_00001951',
#  'GENCODE__ENSG00000132688.11': 'TCONS_00005447',
#  'GENCODE__ENSG00000143320.9': 'TCONS_00005449',
#  'GENCODE__ENSG00000143319.17': 'TCONS_00001952',
#  'GENCODE__ENSG00000143314.12': 'TCONS_00001955',
#  'GENCODE__ENSG00000143321.19': 'TCONS_00005461',
#  'GENCODE__ENSG00000027869.12': 'TCONS_00011044',
#  'GENCODE__ENSG00000117036.12': 'TCONS_00005466',
#  'GENCODE__ENSG00000158710.15': 'TCONS_00001969',
#  'GENCODE__ENSG00000085552.18': 'TCONS_00001970',
#  'GENCODE__ENSG00000162729.14': 'TCONS_00001973',
#  'GENCODE__ENSG00000132716.19': 'TCONS_00001980',
#  'GENCODE__ENSG00000162735.19': 'TCONS_00005484',
#  'GENCODE__ENSG00000122218.17': 'TCONS_00001984',
#  'GENCODE__ENSG00000117090.16': 'TCONS_00005493',
#  'GENCODE__ENSG00000117091.10': 'TCONS_00005494',
#  'GENCODE__ENSG00000179914.5': 'TCONS_00005495',
#  'GENCODE__ENSG00000215845.11': 'TCONS_00001985',
#  'GENCODE__ENSG00000158773.14': 'TCONS_00005501',
#  'GENCODE__ENSG00000186517.14': 'TCONS_00005502',
#  'GENCODE__ENSG00000143217.9': 'TCONS_00005506',
#  'GENCODE__ENSG00000143256.5': 'TCONS_00001993',
#  'GENCODE__ENSG00000158796.17': 'TCONS_00001994',
#  'GENCODE__ENSG00000158850.15': 'TCONS_00005514',
#  'GENCODE__ENSG00000158874.11': 'TCONS_00001996',
#  'GENCODE__ENSG00000162747.13': 'TCONS_00005517',
#  'GENCODE__ENSG00000143149.13': 'TCONS_00007737',
#  'GENCODE__ENSG00000143183.18': 'TCONS_00005520',
#  'GENCODE__ENSG00000152382.6': 'TCONS_00005524',
#  'GENCODE__ENSG00000143167.12': 'TCONS_00002003',
#  'GENCODE__ENSG00000198821.12': 'TCONS_00007744',
#  'GENCODE__ENSG00000143162.9': 'TCONS_00005530',
#  'GENCODE__ENSG00000143158.11': 'TCONS_00002007',
#  'GENCODE__ENSG00000224837.1': 'TCONS_00005532',
#  'GENCODE__ENSG00000143147.15': 'TCONS_00005533',
#  'RefSeq__ANKRD36BP1': 'TCONS_00005536',
#  'GENCODE__ENSG00000214262.5': 'TCONS_00005537',
#  'GENCODE__ENSG00000143156.14': 'TCONS_00005540',
#  'GENCODE__ENSG00000188404.10': 'TCONS_00012308',
#  'GENCODE__ENSG00000171806.12': 'TCONS_00005544',
#  'GENCODE__ENSG00000000457.14': 'TCONS_00005548',
#  'GENCODE__ENSG00000075945.13': 'TCONS_00002010',
#  'GENCODE__ENSG00000117533.15': 'TCONS_00005555',
#  'LOC102724528': 'TCONS_00002012',
#  'GENCODE__ENSG00000135845.10': 'TCONS_00002013',
#  'GENCODE__ENSG00000234741.10': 'TCONS_00005574',
#  'GENCODE__ENSG00000287697.1': 'TCONS_00002018',
#  'GENCODE__ENSG00000120333.4': 'TCONS_00002019',
#  'GENCODE__ENSG00000235750.10': 'TCONS_00002020',
#  'GENCODE__ENSG00000143207.21': 'TCONS_00002023',
#  'GENCODE__ENSG00000293477.1': 'TCONS_00002028',
#  'GENCODE__ENSG00000169905.13': 'TCONS_00005598',
#  'GENCODE__ENSG00000230124.8': 'TCONS_00002032',
#  'GENCODE__ENSG00000135821.19': 'TCONS_00002036',
#  'GENCODE__ENSG00000135828.11': 'TCONS_00005605',
#  ...}
